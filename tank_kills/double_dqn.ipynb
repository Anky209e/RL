# %%
from tanke_dodge import TankDodge
from collections import deque
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import random
import numpy as np
import copy
import os
import pygame

from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter('runs/double_dqn_tank_dodge')
# Out:
# /home/anky/Github/RL/.venv/lib/python3.13/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
class VfApproxModel(nn.Module):
    """Neural Network for Value Function Approximation
    Contains Three layers (state_size)->32->32->4
    """
    def __init__(self, state_size):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=state_size, out_features=32)
        self.layer_2 = nn.Linear(in_features=32, out_features=32)
        self.layer_3 = nn.Linear(in_features=32, out_features=4) # 4 actions as output
        self.relu = nn.ReLU()
    
    def forward(self, features):
        out = self.relu(self.layer_1(features))
        out = self.relu(self.layer_2(out))
        out = self.layer_3(out)
        return out

# %%
class Agent:
    def __init__(self, replay_length, learning_rate, epsilon, max_epsilon, min_epsilon, epsilon_decay, gamma, action_size, value_function, target_value_function):
        self.replay_memory = deque(maxlen=replay_length)
        self.learning_rate = learning_rate
        self.epsilon = epsilon
        self.max_epsilon = max_epsilon
        self.min_epsilon = min_epsilon
        self.epsilon_decay = epsilon_decay
        self.gamma = gamma
        self.action_size = action_size
        self.value_function = value_function
        self.target_value_function = target_value_function
        self.loss_fn = nn.SmoothL1Loss().to(device)
        self.opt  = torch.optim.AdamW(value_function.parameters(), lr=learning_rate, amsgrad=True)
        self.epsilon_list = []
        self.losses =  []

    def add_experience(self, new_state, reward, running, state, action):
        self.replay_memory.append((new_state, reward, running, state, action))
    
    def action(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.randint(0, self.action_size)
        out = self.value_function(state)
        out = out.cpu().detach().numpy()
        return np.argmax(out)
    
    def greedy_action(self, state):
        out = self.value_function(state)
        out = out.cpu().detach().numpy()
        return np.argmax(out)
    
    def replay(self, batch_size, episode):
        batch = random.sample(self.replay_memory, batch_size)
        losses = []
        for new_state, reward, running, state, action in batch:
            q_values = self.value_function(state)
            q_value = q_values[0, action]
            with torch.no_grad():
                # Double DQN target calculation
                next_q_values = self.value_function(new_state)
                next_action = torch.argmax(next_q_values, dim=1)
                target_q_values = self.target_value_function(new_state)
                max_next_q = target_q_values[0, next_action]
                # Reward clipping
                reward = np.clip(reward, -1, 1)
                target = reward + self.gamma * max_next_q * float(running)
            loss = self.loss_fn(q_value, target)
            self.opt.zero_grad()
            loss.backward()
            self.opt.step()
            losses.append(loss.item())
        return np.mean(losses) if losses else 0.0

    def update_target(self):
        self.target_value_function.load_state_dict(self.value_function.state_dict())

    def save_weights(self, path):
        torch.save(self.value_function.state_dict(), path)

# %%
env = TankDodge(num_enemies=3)
state_size = 2 + 2 * env.num_enemies  # [tank_x, tank_y, enemy1_x, enemy1_y, ...]
value_function = VfApproxModel(state_size).to(device)
target_value_function = copy.deepcopy(value_function).to(device)

# %%
num_episodes = 15000
learning_rate = 0.0005
discount_factor = 0.99
exploration_rate = 1
max_exploration_rate = 1
min_exploration_rate = 0.04
exploration_decay_rate = 0.01
replay_length = 5000
batch_size = 128
target_update_freq = 100

agent = Agent(
    replay_length=replay_length,
    learning_rate=learning_rate,
    epsilon=exploration_rate,
    max_epsilon=max_exploration_rate,
    min_epsilon=min_exploration_rate,
    epsilon_decay=exploration_decay_rate,
    gamma=discount_factor,
    action_size=4,
    value_function=value_function,
    target_value_function=target_value_function
)

# %%
losses_per_episode = []
rewards_history = []
for episode in range(num_episodes):
    print(f"-----Episode: [{episode+1}/{num_episodes}]-----")
    state = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    running = True
    actions_taken_per_episode = 0
    rewards_per_episode = 0
    steps = 0
    while running:
        torch.cuda.empty_cache()
        action = agent.action(state)
        next_state, reward, done, _ = env.step(action)
        next_state = torch.tensor(next_state, dtype=torch.float32, device=device).unsqueeze(0)
        agent.add_experience(next_state, reward, not done, state, action)
        state = next_state
        rewards_per_episode += reward
        actions_taken_per_episode += 1
        running = not done
        steps += 1

    agent.epsilon = (agent.max_epsilon-agent.min_epsilon) * np.exp(-agent.epsilon_decay*episode) + agent.min_epsilon
    pygame.display.quit()

    if len(agent.replay_memory) > batch_size:
        replay_loss = agent.replay(batch_size, episode)
        writer.add_scalar("Replay Loss", replay_loss, episode)
    
    writer.add_scalar("Reward per Episode", rewards_per_episode, episode)
    writer.add_scalar("Actions Taken per Episode", actions_taken_per_episode, episode)
    writer.add_scalar("Epsilon per episode", agent.epsilon, episode)
    print(f"Reward:{rewards_per_episode}")
    print(f"Actions Taken:{actions_taken_per_episode}")
    rewards_history.append(rewards_per_episode)

    # Update target network
    if episode % target_update_freq == 0:
        agent.update_target()

writer.close()
agent.save_weights("saved_weights/double_dqn_last_episode_weights.pth")
# Out:
# -----Episode: [1/15000]-----
# /home/anky/Github/RL/.venv/lib/python3.13/site-packages/torch/nn/modules/loss.py:1042: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
# Reward:148
# Actions Taken:199
# -----Episode: [2/15000]-----
# Reward:97
# Actions Taken:148
# -----Episode: [3/15000]-----
# Reward:163
# Actions Taken:214
# -----Episode: [4/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [5/15000]-----
# Reward:79
# Actions Taken:130
# -----Episode: [6/15000]-----
# Reward:148
# Actions Taken:199
# -----Episode: [7/15000]-----
# Reward:148
# Actions Taken:199
# -----Episode: [8/15000]-----
# Reward:108
# Actions Taken:159
# -----Episode: [9/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [10/15000]-----
# Reward:139
# Actions Taken:190
# -----Episode: [11/15000]-----
# Reward:103
# Actions Taken:154
# -----Episode: [12/15000]-----
# Reward:184
# Actions Taken:235
# -----Episode: [13/15000]-----
# Reward:119
# Actions Taken:170
# -----Episode: [14/15000]-----
# Reward:137
# Actions Taken:188
# -----Episode: [15/15000]-----
# Reward:153
# Actions Taken:204
# -----Episode: [16/15000]-----
# Reward:122
# Actions Taken:173
# -----Episode: [17/15000]-----
# Reward:103
# Actions Taken:154
# -----Episode: [18/15000]-----
# Reward:203
# Actions Taken:254
# -----Episode: [19/15000]-----
# Reward:151
# Actions Taken:202
# -----Episode: [20/15000]-----
# Reward:143
# Actions Taken:194
# -----Episode: [21/15000]-----
# Reward:126
# Actions Taken:177
# -----Episode: [22/15000]-----
# Reward:128
# Actions Taken:179
# -----Episode: [23/15000]-----
# Reward:163
# Actions Taken:214
# -----Episode: [24/15000]-----
# Reward:107
# Actions Taken:158
# -----Episode: [25/15000]-----
# Reward:136
# Actions Taken:187
# -----Episode: [26/15000]-----
# Reward:78
# Actions Taken:129
# -----Episode: [27/15000]-----
# Reward:132
# Actions Taken:183
# -----Episode: [28/15000]-----
# Reward:149
# Actions Taken:200
# -----Episode: [29/15000]-----
# Reward:78
# Actions Taken:129
# -----Episode: [30/15000]-----
# Reward:153
# Actions Taken:204
# -----Episode: [31/15000]-----
# Reward:205
# Actions Taken:256
# -----Episode: [32/15000]-----
# Reward:107
# Actions Taken:158
# -----Episode: [33/15000]-----
# Reward:136
# Actions Taken:187
# -----Episode: [34/15000]-----
# Reward:181
# Actions Taken:232
# -----Episode: [35/15000]-----
# Reward:118
# Actions Taken:169
# -----Episode: [36/15000]-----
# Reward:195
# Actions Taken:246
# -----Episode: [37/15000]-----
# Reward:92
# Actions Taken:143
# -----Episode: [38/15000]-----
# Reward:186
# Actions Taken:237
# -----Episode: [39/15000]-----
# Reward:74
# Actions Taken:125
# -----Episode: [40/15000]-----
# Reward:170
# Actions Taken:221
# -----Episode: [41/15000]-----
# Reward:167
# Actions Taken:218
# -----Episode: [42/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [43/15000]-----
# Reward:160
# Actions Taken:211
# -----Episode: [44/15000]-----
# Reward:178
# Actions Taken:229
# -----Episode: [45/15000]-----
# Reward:74
# Actions Taken:125
# -----Episode: [46/15000]-----
# Reward:71
# Actions Taken:122
# -----Episode: [47/15000]-----
# Reward:129
# Actions Taken:180
# -----Episode: [48/15000]-----
# Reward:211
# Actions Taken:262
# -----Episode: [49/15000]-----
# Reward:141
# Actions Taken:192
# -----Episode: [50/15000]-----
# Reward:115
# Actions Taken:166
# -----Episode: [51/15000]-----
# Reward:150
# Actions Taken:201
# -----Episode: [52/15000]-----
# Reward:106
# Actions Taken:157
# -----Episode: [53/15000]-----
# Reward:258
# Actions Taken:309
# -----Episode: [54/15000]-----
# Reward:196
# Actions Taken:247
# -----Episode: [55/15000]-----
# Reward:161
# Actions Taken:212
# -----Episode: [56/15000]-----
# Reward:189
# Actions Taken:240
# -----Episode: [57/15000]-----
# Reward:76
# Actions Taken:127
# -----Episode: [58/15000]-----
# Reward:107
# Actions Taken:158
# -----Episode: [59/15000]-----
# Reward:169
# Actions Taken:220
# -----Episode: [60/15000]-----
# Reward:145
# Actions Taken:196
# -----Episode: [61/15000]-----
# Reward:104
# Actions Taken:155
# -----Episode: [62/15000]-----
# Reward:177
# Actions Taken:228
# -----Episode: [63/15000]-----
# Reward:247
# Actions Taken:298
# -----Episode: [64/15000]-----
# Reward:66
# Actions Taken:117
# -----Episode: [65/15000]-----
# Reward:122
# Actions Taken:173
# -----Episode: [66/15000]-----
# Reward:239
# Actions Taken:290
# -----Episode: [67/15000]-----
# Reward:131
# Actions Taken:182
# -----Episode: [68/15000]-----
# Reward:137
# Actions Taken:188
# -----Episode: [69/15000]-----
# Reward:237
# Actions Taken:288
# -----Episode: [70/15000]-----
# Reward:95
# Actions Taken:146
# -----Episode: [71/15000]-----
# Reward:184
# Actions Taken:235
# -----Episode: [72/15000]-----
# Reward:150
# Actions Taken:201
# -----Episode: [73/15000]-----
# Reward:237
# Actions Taken:288
# -----Episode: [74/15000]-----
# Reward:145
# Actions Taken:196
# -----Episode: [75/15000]-----
# Reward:250
# Actions Taken:301
# -----Episode: [76/15000]-----
# Reward:114
# Actions Taken:165
# -----Episode: [77/15000]-----
# Reward:213
# Actions Taken:264
# -----Episode: [78/15000]-----
# Reward:47
# Actions Taken:98
# -----Episode: [79/15000]-----
# Reward:263
# Actions Taken:314
# -----Episode: [80/15000]-----
# Reward:114
# Actions Taken:165
# -----Episode: [81/15000]-----
# Reward:125
# Actions Taken:176
# -----Episode: [82/15000]-----
# Reward:148
# Actions Taken:199
# -----Episode: [83/15000]-----
# Reward:304
# Actions Taken:355
# -----Episode: [84/15000]-----
# Reward:128
# Actions Taken:179
# -----Episode: [85/15000]-----
# Reward:51
# Actions Taken:102
# -----Episode: [86/15000]-----
# Reward:86
# Actions Taken:137
# -----Episode: [87/15000]-----
# Reward:128
# Actions Taken:179
# -----Episode: [88/15000]-----
# Reward:53
# Actions Taken:104
# -----Episode: [89/15000]-----
# Reward:27
# Actions Taken:78
# -----Episode: [90/15000]-----
# Reward:271
# Actions Taken:322
# -----Episode: [91/15000]-----
# Reward:127
# Actions Taken:178
# -----Episode: [92/15000]-----
# Reward:89
# Actions Taken:140
# -----Episode: [93/15000]-----
# Reward:119
# Actions Taken:170
# -----Episode: [94/15000]-----
# Reward:227
# Actions Taken:278
# -----Episode: [95/15000]-----
# Reward:179
# Actions Taken:230
# -----Episode: [96/15000]-----
# Reward:126
# Actions Taken:177
# -----Episode: [97/15000]-----
# Reward:51
# Actions Taken:102
# -----Episode: [98/15000]-----
# Reward:79
# Actions Taken:130
# -----Episode: [99/15000]-----
# Reward:53
# Actions Taken:104
# -----Episode: [100/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [101/15000]-----
# Reward:233
# Actions Taken:284
# -----Episode: [102/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [103/15000]-----
# Reward:47
# Actions Taken:98
# -----Episode: [104/15000]-----
# Reward:91
# Actions Taken:142
# -----Episode: [105/15000]-----
# Reward:118
# Actions Taken:169
# -----Episode: [106/15000]-----
# Reward:88
# Actions Taken:139
# -----Episode: [107/15000]-----
# Reward:238
# Actions Taken:289
# -----Episode: [108/15000]-----
# Reward:105
# Actions Taken:156
# -----Episode: [109/15000]-----
# Reward:80
# Actions Taken:131
# -----Episode: [110/15000]-----
# Reward:215
# Actions Taken:266
# -----Episode: [111/15000]-----
# Reward:102
# Actions Taken:153
# -----Episode: [112/15000]-----
# Reward:55
# Actions Taken:106
# -----Episode: [113/15000]-----
# Reward:142
# Actions Taken:193
# -----Episode: [114/15000]-----
# Reward:76
# Actions Taken:127
# -----Episode: [115/15000]-----
# Reward:124
# Actions Taken:175
# -----Episode: [116/15000]-----
# Reward:24
# Actions Taken:75
# -----Episode: [117/15000]-----
# Reward:30
# Actions Taken:81
# -----Episode: [118/15000]-----
# Reward:84
# Actions Taken:135
# -----Episode: [119/15000]-----
# Reward:287
# Actions Taken:338
# -----Episode: [120/15000]-----
# Reward:90
# Actions Taken:141
# -----Episode: [121/15000]-----
# Reward:32
# Actions Taken:83
# -----Episode: [122/15000]-----
# Reward:83
# Actions Taken:134
# -----Episode: [123/15000]-----
# Reward:97
# Actions Taken:148
# -----Episode: [124/15000]-----
# Reward:126
# Actions Taken:177
# -----Episode: [125/15000]-----
# Reward:223
# Actions Taken:274
# -----Episode: [126/15000]-----
# Reward:149
# Actions Taken:200
# -----Episode: [127/15000]-----
# Reward:209
# Actions Taken:260
# -----Episode: [128/15000]-----
# Reward:185
# Actions Taken:236
# -----Episode: [129/15000]-----
# Reward:166
# Actions Taken:217
# -----Episode: [130/15000]-----
# Reward:299
# Actions Taken:350
# -----Episode: [131/15000]-----
# Reward:72
# Actions Taken:123
# -----Episode: [132/15000]-----
# Reward:243
# Actions Taken:294
# -----Episode: [133/15000]-----
# Reward:99
# Actions Taken:150
# -----Episode: [134/15000]-----
# Reward:189
# Actions Taken:240
# -----Episode: [135/15000]-----
# Reward:31
# Actions Taken:82
# -----Episode: [136/15000]-----
# Reward:72
# Actions Taken:123
# -----Episode: [137/15000]-----
# Reward:278
# Actions Taken:329
# -----Episode: [138/15000]-----
# Reward:176
# Actions Taken:227
# -----Episode: [139/15000]-----
# Reward:285
# Actions Taken:336
# -----Episode: [140/15000]-----
# Reward:79
# Actions Taken:130
# -----Episode: [141/15000]-----
# Reward:211
# Actions Taken:262
# -----Episode: [142/15000]-----
# Reward:55
# Actions Taken:106
# -----Episode: [143/15000]-----
# Reward:105
# Actions Taken:156
# -----Episode: [144/15000]-----
# Reward:212
# Actions Taken:263
# -----Episode: [145/15000]-----
# Reward:215
# Actions Taken:266
# -----Episode: [146/15000]-----
# Reward:111
# Actions Taken:162
# -----Episode: [147/15000]-----
# Reward:124
# Actions Taken:175
# -----Episode: [148/15000]-----
# Reward:85
# Actions Taken:136
# -----Episode: [149/15000]-----
# Reward:141
# Actions Taken:192
# -----Episode: [150/15000]-----
# Reward:182
# Actions Taken:233
# -----Episode: [151/15000]-----
# Reward:50
# Actions Taken:101
# -----Episode: [152/15000]-----
# Reward:145
# Actions Taken:196
# -----Episode: [153/15000]-----
# Reward:144
# Actions Taken:195
# -----Episode: [154/15000]-----
# Reward:271
# Actions Taken:322
# -----Episode: [155/15000]-----
# Reward:220
# Actions Taken:271
# -----Episode: [156/15000]-----
# Reward:42
# Actions Taken:93
# -----Episode: [157/15000]-----
# Reward:176
# Actions Taken:227
# -----Episode: [158/15000]-----
# Reward:193
# Actions Taken:244
# -----Episode: [159/15000]-----
# Reward:26
# Actions Taken:77
# -----Episode: [160/15000]-----
# Reward:151
# Actions Taken:202
# -----Episode: [161/15000]-----
# Reward:65
# Actions Taken:116
# -----Episode: [162/15000]-----
# Reward:244
# Actions Taken:295
# -----Episode: [163/15000]-----
# Reward:74
# Actions Taken:125
# -----Episode: [164/15000]-----
# Reward:69
# Actions Taken:120
# -----Episode: [165/15000]-----
# Reward:199
# Actions Taken:250
# -----Episode: [166/15000]-----
# Reward:117
# Actions Taken:168
# -----Episode: [167/15000]-----
# Reward:184
# Actions Taken:235
# -----Episode: [168/15000]-----
# Reward:226
# Actions Taken:277
# -----Episode: [169/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [170/15000]-----
# Reward:211
# Actions Taken:262
# -----Episode: [171/15000]-----
# Reward:125
# Actions Taken:176
# -----Episode: [172/15000]-----
# Reward:287
# Actions Taken:338
# -----Episode: [173/15000]-----
# Reward:118
# Actions Taken:169
# -----Episode: [174/15000]-----
# Reward:215
# Actions Taken:266
# -----Episode: [175/15000]-----
# Reward:219
# Actions Taken:270
# -----Episode: [176/15000]-----
# Reward:243
# Actions Taken:294
# -----Episode: [177/15000]-----
# Reward:107
# Actions Taken:158
# -----Episode: [178/15000]-----
# Reward:279
# Actions Taken:330
# -----Episode: [179/15000]-----
# Reward:116
# Actions Taken:167
# -----Episode: [180/15000]-----
# Reward:96
# Actions Taken:147
# -----Episode: [181/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [182/15000]-----
# Reward:50
# Actions Taken:101
# -----Episode: [183/15000]-----
# Reward:178
# Actions Taken:229
# -----Episode: [184/15000]-----
# Reward:139
# Actions Taken:190
# -----Episode: [185/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [186/15000]-----
# Reward:226
# Actions Taken:277
# -----Episode: [187/15000]-----
# Reward:172
# Actions Taken:223
# -----Episode: [188/15000]-----
# Reward:204
# Actions Taken:255
# -----Episode: [189/15000]-----
# Reward:189
# Actions Taken:240
# -----Episode: [190/15000]-----
# Reward:187
# Actions Taken:238
# -----Episode: [191/15000]-----
# Reward:48
# Actions Taken:99
# -----Episode: [192/15000]-----
# Reward:129
# Actions Taken:180
# -----Episode: [193/15000]-----
# Reward:238
# Actions Taken:289
# -----Episode: [194/15000]-----
# Reward:184
# Actions Taken:235
# -----Episode: [195/15000]-----
# Reward:99
# Actions Taken:150
# -----Episode: [196/15000]-----
# Reward:17
# Actions Taken:68
# -----Episode: [197/15000]-----
# Reward:102
# Actions Taken:153
# -----Episode: [198/15000]-----
# Reward:25
# Actions Taken:76
# -----Episode: [199/15000]-----
# Reward:93
# Actions Taken:144
# -----Episode: [200/15000]-----
# Reward:175
# Actions Taken:226
# -----Episode: [201/15000]-----
# Reward:200
# Actions Taken:251
# -----Episode: [202/15000]-----
# Reward:193
# Actions Taken:244
# -----Episode: [203/15000]-----
# Reward:162
# Actions Taken:213
# -----Episode: [204/15000]-----
# Reward:152
# Actions Taken:203
# -----Episode: [205/15000]-----
# Reward:302
# Actions Taken:353
# -----Episode: [206/15000]-----
# Reward:232
# Actions Taken:283
# -----Episode: [207/15000]-----
# Reward:90
# Actions Taken:141
# -----Episode: [208/15000]-----
# Reward:235
# Actions Taken:286
# -----Episode: [209/15000]-----
# Reward:355
# Actions Taken:406
# -----Episode: [210/15000]-----
# Reward:118
# Actions Taken:169
# -----Episode: [211/15000]-----
# Reward:179
# Actions Taken:230
# -----Episode: [212/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [213/15000]-----
# Reward:93
# Actions Taken:144
# -----Episode: [214/15000]-----
# Reward:77
# Actions Taken:128
# -----Episode: [215/15000]-----
# Reward:93
# Actions Taken:144
# -----Episode: [216/15000]-----
# Reward:108
# Actions Taken:159
# -----Episode: [217/15000]-----
# Reward:15
# Actions Taken:66
# -----Episode: [218/15000]-----
# Reward:208
# Actions Taken:259
# -----Episode: [219/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [220/15000]-----
# Reward:276
# Actions Taken:327
# -----Episode: [221/15000]-----
# Reward:83
# Actions Taken:134
# -----Episode: [222/15000]-----
# Reward:126
# Actions Taken:177
# -----Episode: [223/15000]-----
# Reward:167
# Actions Taken:218
# -----Episode: [224/15000]-----
# Reward:129
# Actions Taken:180
# -----Episode: [225/15000]-----
# Reward:65
# Actions Taken:116
# -----Episode: [226/15000]-----
# Reward:40
# Actions Taken:91
# -----Episode: [227/15000]-----
# Reward:109
# Actions Taken:160
# -----Episode: [228/15000]-----
# Reward:102
# Actions Taken:153
# -----Episode: [229/15000]-----
# Reward:62
# Actions Taken:113
# -----Episode: [230/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [231/15000]-----
# Reward:188
# Actions Taken:239
# -----Episode: [232/15000]-----
# Reward:140
# Actions Taken:191
# -----Episode: [233/15000]-----
# Reward:235
# Actions Taken:286
# -----Episode: [234/15000]-----
# Reward:207
# Actions Taken:258
# -----Episode: [235/15000]-----
# Reward:70
# Actions Taken:121
# -----Episode: [236/15000]-----
# Reward:211
# Actions Taken:262
# -----Episode: [237/15000]-----
# Reward:241
# Actions Taken:292
# -----Episode: [238/15000]-----
# Reward:180
# Actions Taken:231
# -----Episode: [239/15000]-----
# Reward:56
# Actions Taken:107
# -----Episode: [240/15000]-----
# Reward:203
# Actions Taken:254
# -----Episode: [241/15000]-----
# Reward:12
# Actions Taken:63
# -----Episode: [242/15000]-----
# Reward:135
# Actions Taken:186
# -----Episode: [243/15000]-----
# Reward:32
# Actions Taken:83
# -----Episode: [244/15000]-----
# Reward:10
# Actions Taken:61
# -----Episode: [245/15000]-----
# Reward:74
# Actions Taken:125
# -----Episode: [246/15000]-----
# Reward:206
# Actions Taken:257
# -----Episode: [247/15000]-----
# Reward:180
# Actions Taken:231
# -----Episode: [248/15000]-----
# Reward:63
# Actions Taken:114
# -----Episode: [249/15000]-----
# Reward:54
# Actions Taken:105
# -----Episode: [250/15000]-----
# Reward:87
# Actions Taken:138
# -----Episode: [251/15000]-----
# Reward:16
# Actions Taken:67
# -----Episode: [252/15000]-----
# Reward:150
# Actions Taken:201
# -----Episode: [253/15000]-----
# Reward:55
# Actions Taken:106
# -----Episode: [254/15000]-----
# Reward:112
# Actions Taken:163
# -----Episode: [255/15000]-----
# Reward:79
# Actions Taken:130
# -----Episode: [256/15000]-----
# Reward:155
# Actions Taken:206
# -----Episode: [257/15000]-----
# Reward:321
# Actions Taken:372
# -----Episode: [258/15000]-----
# Reward:119
# Actions Taken:170
# -----Episode: [259/15000]-----
# Reward:167
# Actions Taken:218
# -----Episode: [260/15000]-----
# Reward:58
# Actions Taken:109
# -----Episode: [261/15000]-----
# Reward:209
# Actions Taken:260
# -----Episode: [262/15000]-----
# Reward:215
# Actions Taken:266
# -----Episode: [263/15000]-----
# Reward:228
# Actions Taken:279
# -----Episode: [264/15000]-----
# Reward:154
# Actions Taken:205
# -----Episode: [265/15000]-----
# Reward:33
# Actions Taken:84
# -----Episode: [266/15000]-----
# Reward:50
# Actions Taken:101
# -----Episode: [267/15000]-----
# Reward:22
# Actions Taken:73
# -----Episode: [268/15000]-----
# Reward:71
# Actions Taken:122
# -----Episode: [269/15000]-----
# Reward:30
# Actions Taken:81
# -----Episode: [270/15000]-----
# Reward:44
# Actions Taken:95
# -----Episode: [271/15000]-----
# Reward:230
# Actions Taken:281
# -----Episode: [272/15000]-----
# Reward:219
# Actions Taken:270
# -----Episode: [273/15000]-----
# Reward:15
# Actions Taken:66
# -----Episode: [274/15000]-----
# Reward:14
# Actions Taken:65
# -----Episode: [275/15000]-----
# Reward:60
# Actions Taken:111
# -----Episode: [276/15000]-----
# Reward:59
# Actions Taken:110
# -----Episode: [277/15000]-----
# Reward:13
# Actions Taken:64
# -----Episode: [278/15000]-----
# Reward:50
# Actions Taken:101
# -----Episode: [279/15000]-----
# Reward:93
# Actions Taken:144
# -----Episode: [280/15000]-----
# Reward:78
# Actions Taken:129
# -----Episode: [281/15000]-----
# Reward:235
# Actions Taken:286
# -----Episode: [282/15000]-----
# Reward:197
# Actions Taken:248
# -----Episode: [283/15000]-----
# Reward:167
# Actions Taken:218
# -----Episode: [284/15000]-----
# Reward:176
# Actions Taken:227
# -----Episode: [285/15000]-----
# Reward:148
# Actions Taken:199
# -----Episode: [286/15000]-----
# Reward:9
# Actions Taken:60
# -----Episode: [287/15000]-----
# Reward:59
# Actions Taken:110
# -----Episode: [288/15000]-----
# Reward:88
# Actions Taken:139
# -----Episode: [289/15000]-----
# Reward:44
# Actions Taken:95
# -----Episode: [290/15000]-----
# Reward:40
# Actions Taken:91
# -----Episode: [291/15000]-----
# Reward:175
# Actions Taken:226
# -----Episode: [292/15000]-----
# Reward:68
# Actions Taken:119
# -----Episode: [293/15000]-----
# Reward:134
# Actions Taken:185
# -----Episode: [294/15000]-----
# Reward:132
# Actions Taken:183
# -----Episode: [295/15000]-----
# Reward:87
# Actions Taken:138
# -----Episode: [296/15000]-----
# Reward:72
# Actions Taken:123
# -----Episode: [297/15000]-----
# Reward:201
# Actions Taken:252
# -----Episode: [298/15000]-----
# Reward:229
# Actions Taken:280
# -----Episode: [299/15000]-----
# Reward:142
# Actions Taken:193
# -----Episode: [300/15000]-----
# Reward:123
# Actions Taken:174
# -----Episode: [301/15000]-----
# Reward:87
# Actions Taken:138
# -----Episode: [302/15000]-----
# Reward:186
# Actions Taken:237
# -----Episode: [303/15000]-----
# Reward:40
# Actions Taken:91
# -----Episode: [304/15000]-----
# Reward:192
# Actions Taken:243
# -----Episode: [305/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [306/15000]-----
# Reward:184
# Actions Taken:235
# -----Episode: [307/15000]-----
# Reward:195
# Actions Taken:246
# -----Episode: [308/15000]-----
# Reward:48
# Actions Taken:99
# -----Episode: [309/15000]-----
# Reward:140
# Actions Taken:191
# -----Episode: [310/15000]-----
# Reward:72
# Actions Taken:123
# -----Episode: [311/15000]-----
# Reward:57
# Actions Taken:108
# -----Episode: [312/15000]-----
# Reward:104
# Actions Taken:155
# -----Episode: [313/15000]-----
# Reward:41
# Actions Taken:92
# -----Episode: [314/15000]-----
# Reward:50
# Actions Taken:101
# -----Episode: [315/15000]-----
# Reward:35
# Actions Taken:86
# -----Episode: [316/15000]-----
# Reward:228
# Actions Taken:279
# -----Episode: [317/15000]-----
# Reward:201
# Actions Taken:252
# -----Episode: [318/15000]-----
# Reward:133
# Actions Taken:184
# -----Episode: [319/15000]-----
# Reward:222
# Actions Taken:273
# -----Episode: [320/15000]-----
# Reward:254
# Actions Taken:305
# -----Episode: [321/15000]-----
# Reward:186
# Actions Taken:237
# -----Episode: [322/15000]-----
# Reward:52
# Actions Taken:103
# -----Episode: [323/15000]-----
# Reward:226
# Actions Taken:277
# -----Episode: [324/15000]-----
# Reward:76
# Actions Taken:127
# -----Episode: [325/15000]-----
# Reward:42
# Actions Taken:93
# -----Episode: [326/15000]-----
# Reward:151
# Actions Taken:202
# -----Episode: [327/15000]-----
# Reward:183
# Actions Taken:234
# -----Episode: [328/15000]-----
# Reward:124
# Actions Taken:175
# -----Episode: [329/15000]-----
# Reward:107
# Actions Taken:158
# -----Episode: [330/15000]-----
# Reward:83
# Actions Taken:134
# -----Episode: [331/15000]-----
# Reward:172
# Actions Taken:223
# -----Episode: [332/15000]-----
# Reward:124
# Actions Taken:175
# -----Episode: [333/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [334/15000]-----
# Reward:224
# Actions Taken:275
# -----Episode: [335/15000]-----
# Reward:158
# Actions Taken:209
# -----Episode: [336/15000]-----
# Reward:152
# Actions Taken:203
# -----Episode: [337/15000]-----
# Reward:148
# Actions Taken:199
# -----Episode: [338/15000]-----
# Reward:195
# Actions Taken:246
# -----Episode: [339/15000]-----
# Reward:86
# Actions Taken:137
# -----Episode: [340/15000]-----
# Reward:185
# Actions Taken:236
# -----Episode: [341/15000]-----
# Reward:83
# Actions Taken:134
# -----Episode: [342/15000]-----
# Reward:198
# Actions Taken:249
# -----Episode: [343/15000]-----
# Reward:98
# Actions Taken:149
# -----Episode: [344/15000]-----
# Reward:89
# Actions Taken:140
# -----Episode: [345/15000]-----
# Reward:225
# Actions Taken:276
# -----Episode: [346/15000]-----
# Reward:43
# Actions Taken:94
# -----Episode: [347/15000]-----
# Reward:139
# Actions Taken:190
# -----Episode: [348/15000]-----
# Reward:216
# Actions Taken:267
# -----Episode: [349/15000]-----
# Reward:158
# Actions Taken:209
# -----Episode: [350/15000]-----
# Reward:72
# Actions Taken:123
# -----Episode: [351/15000]-----
# Reward:244
# Actions Taken:295
# -----Episode: [352/15000]-----
# Reward:60
# Actions Taken:111
# -----Episode: [353/15000]-----
# Reward:133
# Actions Taken:184
# -----Episode: [354/15000]-----
# Reward:210
# Actions Taken:261
# -----Episode: [355/15000]-----
# Reward:205
# Actions Taken:256
# -----Episode: [356/15000]-----
# Reward:61
# Actions Taken:112
# -----Episode: [357/15000]-----
# Reward:141
# Actions Taken:192
# -----Episode: [358/15000]-----
# Reward:138
# Actions Taken:189
# -----Episode: [359/15000]-----
# Reward:44
# Actions Taken:95
# -----Episode: [360/15000]-----
# Reward:148
# Actions Taken:199
# -----Episode: [361/15000]-----
# Reward:205
# Actions Taken:256
# -----Episode: [362/15000]-----
# Reward:83
# Actions Taken:134
# -----Episode: [363/15000]-----
# Reward:212
# Actions Taken:263
# -----Episode: [364/15000]-----
# Reward:207
# Actions Taken:258
# -----Episode: [365/15000]-----
# Reward:32
# Actions Taken:83
# -----Episode: [366/15000]-----
# Reward:78
# Actions Taken:129
# -----Episode: [367/15000]-----
# Reward:225
# Actions Taken:276
# -----Episode: [368/15000]-----
# Reward:161
# Actions Taken:212
# -----Episode: [369/15000]-----
# Reward:203
# Actions Taken:254
# -----Episode: [370/15000]-----
# Reward:209
# Actions Taken:260
# -----Episode: [371/15000]-----
# Reward:137
# Actions Taken:188
# -----Episode: [372/15000]-----
# Reward:60
# Actions Taken:111
# -----Episode: [373/15000]-----
# Reward:11
# Actions Taken:62
# -----Episode: [374/15000]-----
# Reward:14
# Actions Taken:65
# -----Episode: [375/15000]-----
# Reward:179
# Actions Taken:230
# -----Episode: [376/15000]-----
# Reward:134
# Actions Taken:185
# -----Episode: [377/15000]-----
# Reward:210
# Actions Taken:261
# -----Episode: [378/15000]-----
# Reward:214
# Actions Taken:265
# -----Episode: [379/15000]-----
# Reward:294
# Actions Taken:345
# -----Episode: [380/15000]-----
# Reward:154
# Actions Taken:205
# -----Episode: [381/15000]-----
# Reward:175
# Actions Taken:226
# -----Episode: [382/15000]-----
# Reward:200
# Actions Taken:251
# -----Episode: [383/15000]-----
# Reward:188
# Actions Taken:239
# -----Episode: [384/15000]-----
# Reward:70
# Actions Taken:121
# -----Episode: [385/15000]-----
# Reward:226
# Actions Taken:277
# -----Episode: [386/15000]-----
# Reward:189
# Actions Taken:240
# -----Episode: [387/15000]-----
# Reward:234
# Actions Taken:285
# -----Episode: [388/15000]-----
# Reward:36
# Actions Taken:87
# -----Episode: [389/15000]-----
# Reward:24
# Actions Taken:75
# -----Episode: [390/15000]-----
# Reward:185
# Actions Taken:236
# -----Episode: [391/15000]-----
# Reward:81
# Actions Taken:132
# -----Episode: [392/15000]-----
# Reward:63
# Actions Taken:114
# -----Episode: [393/15000]-----
# Reward:9
# Actions Taken:60
# -----Episode: [394/15000]-----
# Reward:187
# Actions Taken:238
# -----Episode: [395/15000]-----
# Reward:177
# Actions Taken:228
# -----Episode: [396/15000]-----
# Reward:151
# Actions Taken:202
# -----Episode: [397/15000]-----
# Reward:223
# Actions Taken:274
# -----Episode: [398/15000]-----
# Reward:208
# Actions Taken:259
# -----Episode: [399/15000]-----
# Reward:183
# Actions Taken:234
# -----Episode: [400/15000]-----
# Reward:173
# Actions Taken:224
# -----Episode: [401/15000]-----
# Reward:68
# Actions Taken:119
# -----Episode: [402/15000]-----
# Reward:178
# Actions Taken:229
# -----Episode: [403/15000]-----
# Reward:21
# Actions Taken:72
# -----Episode: [404/15000]-----
# Reward:9
# Actions Taken:60
# -----Episode: [405/15000]-----
# Reward:109
# Actions Taken:160
# -----Episode: [406/15000]-----
# Reward:153
# Actions Taken:204
# -----Episode: [407/15000]-----
# Reward:60
# Actions Taken:111
# -----Episode: [408/15000]-----
# Reward:39
# Actions Taken:90
# -----Episode: [409/15000]-----
# Reward:241
# Actions Taken:292
# -----Episode: [410/15000]-----
# Reward:204
# Actions Taken:255
# -----Episode: [411/15000]-----
# Reward:154
# Actions Taken:205
# -----Episode: [412/15000]-----
# Reward:42
# Actions Taken:93
# -----Episode: [413/15000]-----
# Reward:199
# Actions Taken:250
# -----Episode: [414/15000]-----
# Reward:190
# Actions Taken:241
# -----Episode: [415/15000]-----
# Reward:248
# Actions Taken:299
# -----Episode: [416/15000]-----
# Reward:99
# Actions Taken:150
# -----Episode: [417/15000]-----
# Reward:228
# Actions Taken:279
# -----Episode: [418/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [419/15000]-----
# Reward:209
# Actions Taken:260
# -----Episode: [420/15000]-----
# Reward:25
# Actions Taken:76
# -----Episode: [421/15000]-----
# Reward:48
# Actions Taken:99
# -----Episode: [422/15000]-----
# Reward:194
# Actions Taken:245
# -----Episode: [423/15000]-----
# Reward:178
# Actions Taken:229
# -----Episode: [424/15000]-----
# Reward:206
# Actions Taken:257
# -----Episode: [425/15000]-----
# Reward:183
# Actions Taken:234
# -----Episode: [426/15000]-----
# Reward:67
# Actions Taken:118
# -----Episode: [427/15000]-----
# Reward:85
# Actions Taken:136
# -----Episode: [428/15000]-----
# Reward:32
# Actions Taken:83
# -----Episode: [429/15000]-----
# Reward:64
# Actions Taken:115
# -----Episode: [430/15000]-----
# Reward:134
# Actions Taken:185
# -----Episode: [431/15000]-----
# Reward:212
# Actions Taken:263
# -----Episode: [432/15000]-----
# Reward:182
# Actions Taken:233
# -----Episode: [433/15000]-----
# Reward:203
# Actions Taken:254
# -----Episode: [434/15000]-----
# Reward:86
# Actions Taken:137
# -----Episode: [435/15000]-----
# Reward:77
# Actions Taken:128
# -----Episode: [436/15000]-----
# Reward:188
# Actions Taken:239
# -----Episode: [437/15000]-----
# Reward:127
# Actions Taken:178
# -----Episode: [438/15000]-----
# Reward:21
# Actions Taken:72
# -----Episode: [439/15000]-----
# Reward:197
# Actions Taken:248
# -----Episode: [440/15000]-----
# Reward:160
# Actions Taken:211
# -----Episode: [441/15000]-----
# Reward:38
# Actions Taken:89
# -----Episode: [442/15000]-----
# Reward:230
# Actions Taken:281
# -----Episode: [443/15000]-----
# Reward:162
# Actions Taken:213
# -----Episode: [444/15000]-----
# Reward:253
# Actions Taken:304
# -----Episode: [445/15000]-----
# Reward:63
# Actions Taken:114
# -----Episode: [446/15000]-----
# Reward:36
# Actions Taken:87
# -----Episode: [447/15000]-----
# Reward:45
# Actions Taken:96
# -----Episode: [448/15000]-----
# Reward:23
# Actions Taken:74
# -----Episode: [449/15000]-----
# Reward:177
# Actions Taken:228
# -----Episode: [450/15000]-----
# Reward:167
# Actions Taken:218
# -----Episode: [451/15000]-----
# Reward:17
# Actions Taken:68
# -----Episode: [452/15000]-----
# Reward:131
# Actions Taken:182
# -----Episode: [453/15000]-----
# Reward:47
# Actions Taken:98
# -----Episode: [454/15000]-----
# Reward:184
# Actions Taken:235
# -----Episode: [455/15000]-----
# Reward:175
# Actions Taken:226
# -----Episode: [456/15000]-----
# Reward:185
# Actions Taken:236
# -----Episode: [457/15000]-----
# Reward:56
# Actions Taken:107
# -----Episode: [458/15000]-----
# Reward:39
# Actions Taken:90
# -----Episode: [459/15000]-----
# Reward:47
# Actions Taken:98
# -----Episode: [460/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [461/15000]-----
# Reward:156
# Actions Taken:207
# -----Episode: [462/15000]-----
# Reward:14
# Actions Taken:65
# -----Episode: [463/15000]-----
# Reward:47
# Actions Taken:98
# -----Episode: [464/15000]-----
# Reward:206
# Actions Taken:257
# -----Episode: [465/15000]-----
# Reward:189
# Actions Taken:240
# -----Episode: [466/15000]-----
# Reward:184
# Actions Taken:235
# -----Episode: [467/15000]-----
# Reward:95
# Actions Taken:146
# -----Episode: [468/15000]-----
# Reward:68
# Actions Taken:119
# -----Episode: [469/15000]-----
# Reward:108
# Actions Taken:159
# -----Episode: [470/15000]-----
# Reward:174
# Actions Taken:225
# -----Episode: [471/15000]-----
# Reward:79
# Actions Taken:130
# -----Episode: [472/15000]-----
# Reward:183
# Actions Taken:234
# -----Episode: [473/15000]-----
# Reward:48
# Actions Taken:99
# -----Episode: [474/15000]-----
# Reward:72
# Actions Taken:123
# -----Episode: [475/15000]-----
# Reward:177
# Actions Taken:228
# -----Episode: [476/15000]-----
# Reward:207
# Actions Taken:258
# -----Episode: [477/15000]-----
# Reward:182
# Actions Taken:233
# -----Episode: [478/15000]-----
# Reward:233
# Actions Taken:284
# -----Episode: [479/15000]-----
# Reward:212
# Actions Taken:263
# -----Episode: [480/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [481/15000]-----
# Reward:185
# Actions Taken:236
# -----Episode: [482/15000]-----
# Reward:229
# Actions Taken:280
# -----Episode: [483/15000]-----
# Reward:215
# Actions Taken:266
# -----Episode: [484/15000]-----
# Reward:218
# Actions Taken:269
# -----Episode: [485/15000]-----
# Reward:212
# Actions Taken:263
# -----Episode: [486/15000]-----
# Reward:118
# Actions Taken:169
# -----Episode: [487/15000]-----
# Reward:184
# Actions Taken:235
# -----Episode: [488/15000]-----
# Reward:195
# Actions Taken:246
# -----Episode: [489/15000]-----
# Reward:117
# Actions Taken:168
# -----Episode: [490/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [491/15000]-----
# Reward:155
# Actions Taken:206
# -----Episode: [492/15000]-----
# Reward:122
# Actions Taken:173
# -----Episode: [493/15000]-----
# Reward:229
# Actions Taken:280
# -----Episode: [494/15000]-----
# Reward:188
# Actions Taken:239
# -----Episode: [495/15000]-----
# Reward:200
# Actions Taken:251
# -----Episode: [496/15000]-----
# Reward:274
# Actions Taken:325
# -----Episode: [497/15000]-----
# Reward:216
# Actions Taken:267
# -----Episode: [498/15000]-----
# Reward:281
# Actions Taken:332
# -----Episode: [499/15000]-----
# Reward:63
# Actions Taken:114
# -----Episode: [500/15000]-----
# Reward:229
# Actions Taken:280
# -----Episode: [501/15000]-----
# Reward:152
# Actions Taken:203
# -----Episode: [502/15000]-----
# Reward:152
# Actions Taken:203
# -----Episode: [503/15000]-----
# Reward:186
# Actions Taken:237
# -----Episode: [504/15000]-----
# Reward:160
# Actions Taken:211
# -----Episode: [505/15000]-----
# Reward:55
# Actions Taken:106
# -----Episode: [506/15000]-----
# Reward:18
# Actions Taken:69
# -----Episode: [507/15000]-----
# Reward:15
# Actions Taken:66
# -----Episode: [508/15000]-----
# Reward:75
# Actions Taken:126
# -----Episode: [509/15000]-----
# Reward:69
# Actions Taken:120
# -----Episode: [510/15000]-----
# Reward:244
# Actions Taken:295
# -----Episode: [511/15000]-----
# Reward:146
# Actions Taken:197
# -----Episode: [512/15000]-----
# Reward:226
# Actions Taken:277
# -----Episode: [513/15000]-----
# Reward:61
# Actions Taken:112
# -----Episode: [514/15000]-----
# Reward:201
# Actions Taken:252
# -----Episode: [515/15000]-----
# Reward:34
# Actions Taken:85
# -----Episode: [516/15000]-----
# Reward:184
# Actions Taken:235
# -----Episode: [517/15000]-----
# Reward:218
# Actions Taken:269
# -----Episode: [518/15000]-----
# Reward:205
# Actions Taken:256
# -----Episode: [519/15000]-----
# Reward:195
# Actions Taken:246
# -----Episode: [520/15000]-----
# Reward:213
# Actions Taken:264
# -----Episode: [521/15000]-----
# Reward:128
# Actions Taken:179
# -----Episode: [522/15000]-----
# Reward:136
# Actions Taken:187
# -----Episode: [523/15000]-----
# Reward:219
# Actions Taken:270
# -----Episode: [524/15000]-----
# Reward:188
# Actions Taken:239
# -----Episode: [525/15000]-----
# Reward:212
# Actions Taken:263
# -----Episode: [526/15000]-----
# Reward:18
# Actions Taken:69
# -----Episode: [527/15000]-----
# Reward:120
# Actions Taken:171
# -----Episode: [528/15000]-----
# Reward:206
# Actions Taken:257
# -----Episode: [529/15000]-----
# Reward:137
# Actions Taken:188
# -----Episode: [530/15000]-----
# Reward:113
# Actions Taken:164
# -----Episode: [531/15000]-----
# Reward:204
# Actions Taken:255
# -----Episode: [532/15000]-----
# Reward:31
# Actions Taken:82
# -----Episode: [533/15000]-----
# Reward:144
# Actions Taken:195
# -----Episode: [534/15000]-----
# Reward:135
# Actions Taken:186
# -----Episode: [535/15000]-----
# Reward:223
# Actions Taken:274
# -----Episode: [536/15000]-----
# Reward:231
# Actions Taken:282
# -----Episode: [537/15000]-----
# Reward:144
# Actions Taken:195
# -----Episode: [538/15000]-----
# Reward:177
# Actions Taken:228
# -----Episode: [539/15000]-----
# Reward:179
# Actions Taken:230
# -----Episode: [540/15000]-----
# Reward:237
# Actions Taken:288
# -----Episode: [541/15000]-----
# Reward:211
# Actions Taken:262
# -----Episode: [542/15000]-----
# Reward:165
# Actions Taken:216
# -----Episode: [543/15000]-----
# Reward:236
# Actions Taken:287
# -----Episode: [544/15000]-----
# Reward:52
# Actions Taken:103
# -----Episode: [545/15000]-----
# Reward:139
# Actions Taken:190
# -----Episode: [546/15000]-----
# Reward:22
# Actions Taken:73
# -----Episode: [547/15000]-----
# Reward:266
# Actions Taken:317
# -----Episode: [548/15000]-----
# Reward:48
# Actions Taken:99
# -----Episode: [549/15000]-----
# Reward:83
# Actions Taken:134
# -----Episode: [550/15000]-----
# Reward:7
# Actions Taken:58
# -----Episode: [551/15000]-----
# Reward:34
# Actions Taken:85
# -----Episode: [552/15000]-----
# Reward:82
# Actions Taken:133
# -----Episode: [553/15000]-----
# Reward:201
# Actions Taken:252
# -----Episode: [554/15000]-----
# Reward:95
# Actions Taken:146
# -----Episode: [555/15000]-----
# Reward:38
# Actions Taken:89
# -----Episode: [556/15000]-----
# Reward:166
# Actions Taken:217
# -----Episode: [557/15000]-----
# Reward:265
# Actions Taken:316
# -----Episode: [558/15000]-----
# Reward:52
# Actions Taken:103
# -----Episode: [559/15000]-----
# Reward:154
# Actions Taken:205
# -----Episode: [560/15000]-----
# Reward:145
# Actions Taken:196
# -----Episode: [561/15000]-----
# Reward:131
# Actions Taken:182
# -----Episode: [562/15000]-----
# Reward:176
# Actions Taken:227
# -----Episode: [563/15000]-----
# Reward:92
# Actions Taken:143
# -----Episode: [564/15000]-----
# Reward:203
# Actions Taken:254
# -----Episode: [565/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [566/15000]-----
# Reward:181
# Actions Taken:232
# -----Episode: [567/15000]-----
# Reward:204
# Actions Taken:255
# -----Episode: [568/15000]-----
# Reward:150
# Actions Taken:201
# -----Episode: [569/15000]-----
# Reward:40
# Actions Taken:91
# -----Episode: [570/15000]-----
# Reward:33
# Actions Taken:84
# -----Episode: [571/15000]-----
# Reward:43
# Actions Taken:94
# -----Episode: [572/15000]-----
# Reward:20
# Actions Taken:71
# -----Episode: [573/15000]-----
# Reward:127
# Actions Taken:178
# -----Episode: [574/15000]-----
# Reward:302
# Actions Taken:353
# -----Episode: [575/15000]-----
# Reward:162
# Actions Taken:213
# -----Episode: [576/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [577/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [578/15000]-----
# Reward:122
# Actions Taken:173
# -----Episode: [579/15000]-----
# Reward:192
# Actions Taken:243
# -----Episode: [580/15000]-----
# Reward:14
# Actions Taken:65
# -----Episode: [581/15000]-----
# Reward:199
# Actions Taken:250
# -----Episode: [582/15000]-----
# Reward:255
# Actions Taken:306
# -----Episode: [583/15000]-----
# Reward:149
# Actions Taken:200
# -----Episode: [584/15000]-----
# Reward:162
# Actions Taken:213
# -----Episode: [585/15000]-----
# Reward:182
# Actions Taken:233
# -----Episode: [586/15000]-----
# Reward:61
# Actions Taken:112
# -----Episode: [587/15000]-----
# Reward:186
# Actions Taken:237
# -----Episode: [588/15000]-----
# Reward:32
# Actions Taken:83
# -----Episode: [589/15000]-----
# Reward:222
# Actions Taken:273
# -----Episode: [590/15000]-----
# Reward:27
# Actions Taken:78
# -----Episode: [591/15000]-----
# Reward:173
# Actions Taken:224
# -----Episode: [592/15000]-----
# Reward:198
# Actions Taken:249
# -----Episode: [593/15000]-----
# Reward:152
# Actions Taken:203
# -----Episode: [594/15000]-----
# Reward:228
# Actions Taken:279
# -----Episode: [595/15000]-----
# Reward:241
# Actions Taken:292
# -----Episode: [596/15000]-----
# Reward:233
# Actions Taken:284
# -----Episode: [597/15000]-----
# Reward:47
# Actions Taken:98
# -----Episode: [598/15000]-----
# Reward:61
# Actions Taken:112
# -----Episode: [599/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [600/15000]-----
# Reward:183
# Actions Taken:234
# -----Episode: [601/15000]-----
# Reward:189
# Actions Taken:240
# -----Episode: [602/15000]-----
# Reward:106
# Actions Taken:157
# -----Episode: [603/15000]-----
# Reward:197
# Actions Taken:248
# -----Episode: [604/15000]-----
# Reward:66
# Actions Taken:117
# -----Episode: [605/15000]-----
# Reward:164
# Actions Taken:215
# -----Episode: [606/15000]-----
# Reward:119
# Actions Taken:170
# -----Episode: [607/15000]-----
# Reward:18
# Actions Taken:69
# -----Episode: [608/15000]-----
# Reward:54
# Actions Taken:105
# -----Episode: [609/15000]-----
# Reward:210
# Actions Taken:261
# -----Episode: [610/15000]-----
# Reward:19
# Actions Taken:70
# -----Episode: [611/15000]-----
# Reward:172
# Actions Taken:223
# -----Episode: [612/15000]-----
# Reward:199
# Actions Taken:250
# -----Episode: [613/15000]-----
# Reward:58
# Actions Taken:109
# -----Episode: [614/15000]-----
# Reward:12
# Actions Taken:63
# -----Episode: [615/15000]-----
# Reward:157
# Actions Taken:208
# -----Episode: [616/15000]-----
# Reward:146
# Actions Taken:197
# -----Episode: [617/15000]-----
# Reward:193
# Actions Taken:244
# -----Episode: [618/15000]-----
# Reward:152
# Actions Taken:203
# -----Episode: [619/15000]-----
# Reward:170
# Actions Taken:221
# -----Episode: [620/15000]-----
# Reward:176
# Actions Taken:227
# -----Episode: [621/15000]-----
# Reward:185
# Actions Taken:236
# -----Episode: [622/15000]-----
# Reward:259
# Actions Taken:310
# -----Episode: [623/15000]-----
# Reward:188
# Actions Taken:239
# -----Episode: [624/15000]-----
# Reward:57
# Actions Taken:108
# -----Episode: [625/15000]-----
# Reward:70
# Actions Taken:121
# -----Episode: [626/15000]-----
# Reward:10
# Actions Taken:61
# -----Episode: [627/15000]-----
# Reward:220
# Actions Taken:271
# -----Episode: [628/15000]-----
# Reward:167
# Actions Taken:218
# -----Episode: [629/15000]-----
# Reward:261
# Actions Taken:312
# -----Episode: [630/15000]-----
# Reward:201
# Actions Taken:252
# -----Episode: [631/15000]-----
# Reward:166
# Actions Taken:217
# -----Episode: [632/15000]-----
# Reward:220
# Actions Taken:271
# -----Episode: [633/15000]-----
# Reward:192
# Actions Taken:243
# -----Episode: [634/15000]-----
# Reward:91
# Actions Taken:142
# -----Episode: [635/15000]-----
# Reward:22
# Actions Taken:73
# -----Episode: [636/15000]-----
# Reward:35
# Actions Taken:86
# -----Episode: [637/15000]-----
# Reward:158
# Actions Taken:209
# -----Episode: [638/15000]-----
# Reward:57
# Actions Taken:108
# -----Episode: [639/15000]-----
# Reward:14
# Actions Taken:65
# -----Episode: [640/15000]-----
# Reward:78
# Actions Taken:129
# -----Episode: [641/15000]-----
# Reward:174
# Actions Taken:225
# -----Episode: [642/15000]-----
# Reward:22
# Actions Taken:73
# -----Episode: [643/15000]-----
# Reward:77
# Actions Taken:128
# -----Episode: [644/15000]-----
# Reward:8
# Actions Taken:59
# -----Episode: [645/15000]-----
# Reward:47
# Actions Taken:98
# -----Episode: [646/15000]-----
# Reward:225
# Actions Taken:276
# -----Episode: [647/15000]-----
# Reward:193
# Actions Taken:244
# -----Episode: [648/15000]-----
# Reward:35
# Actions Taken:86
# -----Episode: [649/15000]-----
# Reward:77
# Actions Taken:128
# -----Episode: [650/15000]-----
# Reward:170
# Actions Taken:221
# -----Episode: [651/15000]-----
# Reward:183
# Actions Taken:234
# -----Episode: [652/15000]-----
# Reward:145
# Actions Taken:196
# -----Episode: [653/15000]-----
# Reward:47
# Actions Taken:98
# -----Episode: [654/15000]-----
# Reward:34
# Actions Taken:85
# -----Episode: [655/15000]-----
# Reward:172
# Actions Taken:223
# -----Episode: [656/15000]-----
# Reward:194
# Actions Taken:245
# -----Episode: [657/15000]-----
# Reward:280
# Actions Taken:331
# -----Episode: [658/15000]-----
# Reward:165
# Actions Taken:216
# -----Episode: [659/15000]-----
# Reward:165
# Actions Taken:216
# -----Episode: [660/15000]-----
# Reward:193
# Actions Taken:244
# -----Episode: [661/15000]-----
# Reward:321
# Actions Taken:372
# -----Episode: [662/15000]-----
# Reward:70
# Actions Taken:121
# -----Episode: [663/15000]-----
# Reward:51
# Actions Taken:102
# -----Episode: [664/15000]-----
# Reward:39
# Actions Taken:90
# -----Episode: [665/15000]-----
# Reward:26
# Actions Taken:77
# -----Episode: [666/15000]-----
# Reward:46
# Actions Taken:97
# -----Episode: [667/15000]-----
# Reward:50
# Actions Taken:101
# -----Episode: [668/15000]-----
# Reward:117
# Actions Taken:168
# -----Episode: [669/15000]-----
# Reward:71
# Actions Taken:122
# -----Episode: [670/15000]-----
# Reward:69
# Actions Taken:120
# -----Episode: [671/15000]-----
# Reward:12
# Actions Taken:63
# -----Episode: [672/15000]-----
# Reward:108
# Actions Taken:159
# -----Episode: [673/15000]-----
# Reward:11
# Actions Taken:62
# -----Episode: [674/15000]-----
# Reward:224
# Actions Taken:275
# -----Episode: [675/15000]-----
# Reward:84
# Actions Taken:135
# -----Episode: [676/15000]-----
# Reward:20
# Actions Taken:71
# -----Episode: [677/15000]-----
# Reward:29
# Actions Taken:80
# -----Episode: [678/15000]-----
# Reward:33
# Actions Taken:84
# -----Episode: [679/15000]-----
# Reward:204
# Actions Taken:255
# -----Episode: [680/15000]-----
# Reward:246
# Actions Taken:297
# -----Episode: [681/15000]-----
# Reward:61
# Actions Taken:112
# -----Episode: [682/15000]-----
# Reward:103
# Actions Taken:154
# -----Episode: [683/15000]-----
# Reward:245
# Actions Taken:296
# -----Episode: [684/15000]-----
# Reward:84
# Actions Taken:135
# -----Episode: [685/15000]-----
# Reward:180
# Actions Taken:231
# -----Episode: [686/15000]-----
# Reward:58
# Actions Taken:109
# -----Episode: [687/15000]-----
# Reward:62
# Actions Taken:113
# -----Episode: [688/15000]-----
# Reward:18
# Actions Taken:69
# -----Episode: [689/15000]-----
# Reward:14
# Actions Taken:65
# -----Episode: [690/15000]-----
# Reward:34
# Actions Taken:85
# -----Episode: [691/15000]-----
# Reward:27
# Actions Taken:78
# -----Episode: [692/15000]-----
# Reward:163
# Actions Taken:214
# -----Episode: [693/15000]-----
# Reward:224
# Actions Taken:275
# -----Episode: [694/15000]-----
# Reward:243
# Actions Taken:294
# -----Episode: [695/15000]-----
# Reward:9
# Actions Taken:60
# -----Episode: [696/15000]-----
# Reward:24
# Actions Taken:75
# -----Episode: [697/15000]-----
# Reward:236
# Actions Taken:287
# -----Episode: [698/15000]-----
# Reward:199
# Actions Taken:250
# -----Episode: [699/15000]-----
# Reward:190
# Actions Taken:241
# -----Episode: [700/15000]-----
# Reward:19
# Actions Taken:70
# -----Episode: [701/15000]-----
# Reward:169
# Actions Taken:220
# -----Episode: [702/15000]-----
# Reward:66
# Actions Taken:117
# -----Episode: [703/15000]-----
# Reward:128
# Actions Taken:179
# -----Episode: [704/15000]-----
# Reward:57
# Actions Taken:108
# -----Episode: [705/15000]-----
# Reward:166
# Actions Taken:217
# -----Episode: [706/15000]-----
# Reward:190
# Actions Taken:241
# -----Episode: [707/15000]-----
# Reward:59
# Actions Taken:110
# -----Episode: [708/15000]-----
# Reward:207
# Actions Taken:258
# -----Episode: [709/15000]-----
# Reward:166
# Actions Taken:217
# -----Episode: [710/15000]-----
# Reward:16
# Actions Taken:67
# -----Episode: [711/15000]-----
# Reward:93
# Actions Taken:144
# -----Episode: [712/15000]-----
# Reward:208
# Actions Taken:259
# -----Episode: [713/15000]-----
# Reward:163
# Actions Taken:214
# -----Episode: [714/15000]-----
# Reward:183
# Actions Taken:234
# -----Episode: [715/15000]-----
# Reward:39
# Actions Taken:90
# -----Episode: [716/15000]-----
# Reward:269
# Actions Taken:320
# -----Episode: [717/15000]-----
# Reward:200
# Actions Taken:251
# -----Episode: [718/15000]-----
# Reward:209
# Actions Taken:260
# -----Episode: [719/15000]-----
# Reward:257
# Actions Taken:308
# -----Episode: [720/15000]-----
# Reward:92
# Actions Taken:143
# -----Episode: [721/15000]-----
# Reward:85
# Actions Taken:136
# -----Episode: [722/15000]-----
# Reward:134
# Actions Taken:185
# -----Episode: [723/15000]-----
# Reward:103
# Actions Taken:154
# -----Episode: [724/15000]-----
# Reward:36
# Actions Taken:87
# -----Episode: [725/15000]-----
# Reward:46
# Actions Taken:97
# -----Episode: [726/15000]-----
# Reward:23
# Actions Taken:74
# -----Episode: [727/15000]-----
# Reward:218
# Actions Taken:269
# -----Episode: [728/15000]-----
# Reward:235
# Actions Taken:286
# -----Episode: [729/15000]-----
# Reward:160
# Actions Taken:211
# -----Episode: [730/15000]-----
# Reward:252
# Actions Taken:303
# -----Episode: [731/15000]-----
# Reward:272
# Actions Taken:323
# -----Episode: [732/15000]-----
# Reward:184
# Actions Taken:235
# -----Episode: [733/15000]-----
# Reward:225
# Actions Taken:276
# -----Episode: [734/15000]-----
# Reward:171
# Actions Taken:222
# -----Episode: [735/15000]-----
# Reward:49
# Actions Taken:100
# -----Episode: [736/15000]-----
# Reward:16
# Actions Taken:67
# -----Episode: [737/15000]-----
# Reward:242
# Actions Taken:293
# -----Episode: [738/15000]-----
# Reward:18
# Actions Taken:69
# -----Episode: [739/15000]-----
# Reward:226
# Actions Taken:277
# -----Episode: [740/15000]-----
# Reward:88
# Actions Taken:139
# -----Episode: [741/15000]-----
# Reward:182
# Actions Taken:233
# -----Episode: [742/15000]-----
# Reward:213
# Actions Taken:264
# -----Episode: [743/15000]-----
# Reward:213
# Actions Taken:264
# -----Episode: [744/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [745/15000]-----
# Reward:216
# Actions Taken:267
# -----Episode: [746/15000]-----
# Reward:34
# Actions Taken:85
# -----Episode: [747/15000]-----
# Reward:157
# Actions Taken:208
# -----Episode: [748/15000]-----
# Reward:150
# Actions Taken:201
# -----Episode: [749/15000]-----
# Reward:146
# Actions Taken:197
# -----Episode: [750/15000]-----
# Reward:215
# Actions Taken:266
# -----Episode: [751/15000]-----
# Reward:43
# Actions Taken:94
# -----Episode: [752/15000]-----
# Reward:33
# Actions Taken:84
# -----Episode: [753/15000]-----
# Reward:252
# Actions Taken:303
# -----Episode: [754/15000]-----
# Reward:160
# Actions Taken:211
# -----Episode: [755/15000]-----
# Reward:75
# Actions Taken:126
# -----Episode: [756/15000]-----
# Reward:27
# Actions Taken:78
# -----Episode: [757/15000]-----
# Reward:247
# Actions Taken:298
# -----Episode: [758/15000]-----
# Reward:42
# Actions Taken:93
# -----Episode: [759/15000]-----
# Reward:280
# Actions Taken:331
# -----Episode: [760/15000]-----
# Reward:35
# Actions Taken:86
# -----Episode: [761/15000]-----
# Reward:220
# Actions Taken:271
# -----Episode: [762/15000]-----
# Reward:63
# Actions Taken:114
# -----Episode: [763/15000]-----
# Reward:36
# Actions Taken:87
# -----Episode: [764/15000]-----
# Reward:31
# Actions Taken:82
# -----Episode: [765/15000]-----
# Reward:212
# Actions Taken:263
# -----Episode: [766/15000]-----
# Reward:221
# Actions Taken:272
# -----Episode: [767/15000]-----
# Reward:32
# Actions Taken:83
# -----Episode: [768/15000]-----
# Reward:78
# Actions Taken:129
# -----Episode: [769/15000]-----
# Reward:214
# Actions Taken:265
# -----Episode: [770/15000]-----
# Reward:254
# Actions Taken:305
# -----Episode: [771/15000]-----
# Reward:221
# Actions Taken:272
# -----Episode: [772/15000]-----
# Reward:113
# Actions Taken:164
# -----Episode: [773/15000]-----
# Reward:179
# Actions Taken:230
# -----Episode: [774/15000]-----
# Reward:165
# Actions Taken:216
# -----Episode: [775/15000]-----
# Reward:226
# Actions Taken:277
# -----Episode: [776/15000]-----
# Reward:216
# Actions Taken:267
# -----Episode: [777/15000]-----
# Reward:212
# Actions Taken:263
# -----Episode: [778/15000]-----
# Reward:229
# Actions Taken:280
# -----Episode: [779/15000]-----
# Reward:19
# Actions Taken:70
# -----Episode: [780/15000]-----
# Reward:232
# Actions Taken:283
# -----Episode: [781/15000]-----
# Reward:239
# Actions Taken:290
# -----Episode: [782/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [783/15000]-----
# Reward:268
# Actions Taken:319
# -----Episode: [784/15000]-----
# Reward:179
# Actions Taken:230
# -----Episode: [785/15000]-----
# Reward:56
# Actions Taken:107
# -----Episode: [786/15000]-----
# Reward:61
# Actions Taken:112
# -----Episode: [787/15000]-----
# Reward:260
# Actions Taken:311
# -----Episode: [788/15000]-----
# Reward:296
# Actions Taken:347
# -----Episode: [789/15000]-----
# Reward:95
# Actions Taken:146
# -----Episode: [790/15000]-----
# Reward:180
# Actions Taken:231
# -----Episode: [791/15000]-----
# Reward:48
# Actions Taken:99
# -----Episode: [792/15000]-----
# Reward:254
# Actions Taken:305
# -----Episode: [793/15000]-----
# Reward:47
# Actions Taken:98
# -----Episode: [794/15000]-----
# Reward:105
# Actions Taken:156
# -----Episode: [795/15000]-----
# Reward:130
# Actions Taken:181
# -----Episode: [796/15000]-----
# Reward:57
# Actions Taken:108
# -----Episode: [797/15000]-----
# Reward:108
# Actions Taken:159
# -----Episode: [798/15000]-----
# Reward:106
# Actions Taken:157
# -----Episode: [799/15000]-----
# Reward:66
# Actions Taken:117
# -----Episode: [800/15000]-----
# Reward:78
# Actions Taken:129
# -----Episode: [801/15000]-----
# Reward:107
# Actions Taken:158
# -----Episode: [802/15000]-----
# Reward:4
# Actions Taken:55
# ...
# Actions Taken:257
# -----Episode: [14742/15000]-----
# Reward:236
# Actions Taken:287
# -----Episode: [14743/15000]-----
# Reward:196
# Actions Taken:247
# -----Episode: [14744/15000]-----
# Reward:225
# Actions Taken:276
# -----Episode: [14745/15000]-----
# Reward:167
# Actions Taken:218
# -----Episode: [14746/15000]-----
# Reward:242
# Actions Taken:293
# -----Episode: [14747/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [14748/15000]-----
# Reward:142
# Actions Taken:193
# -----Episode: [14749/15000]-----
# Reward:199
# Actions Taken:250
# -----Episode: [14750/15000]-----
# Reward:242
# Actions Taken:293
# -----Episode: [14751/15000]-----
# Reward:158
# Actions Taken:209
# -----Episode: [14752/15000]-----
# Reward:166
# Actions Taken:217
# -----Episode: [14753/15000]-----
# Reward:133
# Actions Taken:184
# -----Episode: [14754/15000]-----
# Reward:189
# Actions Taken:240
# -----Episode: [14755/15000]-----
# Reward:160
# Actions Taken:211
# -----Episode: [14756/15000]-----
# Reward:224
# Actions Taken:275
# -----Episode: [14757/15000]-----
# Reward:225
# Actions Taken:276
# -----Episode: [14758/15000]-----
# Reward:247
# Actions Taken:298
# -----Episode: [14759/15000]-----
# Reward:121
# Actions Taken:172
# -----Episode: [14760/15000]-----
# Reward:219
# Actions Taken:270
# -----Episode: [14761/15000]-----
# Reward:218
# Actions Taken:269
# -----Episode: [14762/15000]-----
# Reward:183
# Actions Taken:234
# -----Episode: [14763/15000]-----
# Reward:257
# Actions Taken:308
# -----Episode: [14764/15000]-----
# Reward:136
# Actions Taken:187
# -----Episode: [14765/15000]-----
# Reward:219
# Actions Taken:270
# -----Episode: [14766/15000]-----
# Reward:190
# Actions Taken:241
# -----Episode: [14767/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [14768/15000]-----
# Reward:161
# Actions Taken:212
# -----Episode: [14769/15000]-----
# Reward:247
# Actions Taken:298
# -----Episode: [14770/15000]-----
# Reward:139
# Actions Taken:190
# -----Episode: [14771/15000]-----
# Reward:241
# Actions Taken:292
# -----Episode: [14772/15000]-----
# Reward:262
# Actions Taken:313
# -----Episode: [14773/15000]-----
# Reward:155
# Actions Taken:206
# -----Episode: [14774/15000]-----
# Reward:35
# Actions Taken:86
# -----Episode: [14775/15000]-----
# Reward:160
# Actions Taken:211
# -----Episode: [14776/15000]-----
# Reward:45
# Actions Taken:96
# -----Episode: [14777/15000]-----
# Reward:173
# Actions Taken:224
# -----Episode: [14778/15000]-----
# Reward:160
# Actions Taken:211
# -----Episode: [14779/15000]-----
# Reward:13
# Actions Taken:64
# -----Episode: [14780/15000]-----
# Reward:137
# Actions Taken:188
# -----Episode: [14781/15000]-----
# Reward:216
# Actions Taken:267
# -----Episode: [14782/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [14783/15000]-----
# Reward:46
# Actions Taken:97
# -----Episode: [14784/15000]-----
# Reward:134
# Actions Taken:185
# -----Episode: [14785/15000]-----
# Reward:73
# Actions Taken:124
# -----Episode: [14786/15000]-----
# Reward:110
# Actions Taken:161
# -----Episode: [14787/15000]-----
# Reward:35
# Actions Taken:86
# -----Episode: [14788/15000]-----
# Reward:51
# Actions Taken:102
# -----Episode: [14789/15000]-----
# Reward:40
# Actions Taken:91
# -----Episode: [14790/15000]-----
# Reward:214
# Actions Taken:265
# -----Episode: [14791/15000]-----
# Reward:4
# Actions Taken:55
# -----Episode: [14792/15000]-----
# Reward:202
# Actions Taken:253
# -----Episode: [14793/15000]-----
# Reward:17
# Actions Taken:68
# -----Episode: [14794/15000]-----
# Reward:158
# Actions Taken:209
# -----Episode: [14795/15000]-----
# Reward:232
# Actions Taken:283
# -----Episode: [14796/15000]-----
# Reward:134
# Actions Taken:185
# -----Episode: [14797/15000]-----
# Reward:167
# Actions Taken:218
# -----Episode: [14798/15000]-----
# Reward:231
# Actions Taken:282
# -----Episode: [14799/15000]-----
# Reward:152
# Actions Taken:203
# -----Episode: [14800/15000]-----
# Reward:233
# Actions Taken:284
# -----Episode: [14801/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [14802/15000]-----
# Reward:132
# Actions Taken:183
# -----Episode: [14803/15000]-----
# Reward:44
# Actions Taken:95
# -----Episode: [14804/15000]-----
# Reward:252
# Actions Taken:303
# -----Episode: [14805/15000]-----
# Reward:139
# Actions Taken:190
# -----Episode: [14806/15000]-----
# Reward:132
# Actions Taken:183
# -----Episode: [14807/15000]-----
# Reward:23
# Actions Taken:74
# -----Episode: [14808/15000]-----
# Reward:140
# Actions Taken:191
# -----Episode: [14809/15000]-----
# Reward:114
# Actions Taken:165
# -----Episode: [14810/15000]-----
# Reward:232
# Actions Taken:283
# -----Episode: [14811/15000]-----
# Reward:163
# Actions Taken:214
# -----Episode: [14812/15000]-----
# Reward:124
# Actions Taken:175
# -----Episode: [14813/15000]-----
# Reward:125
# Actions Taken:176
# -----Episode: [14814/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [14815/15000]-----
# Reward:116
# Actions Taken:167
# -----Episode: [14816/15000]-----
# Reward:158
# Actions Taken:209
# -----Episode: [14817/15000]-----
# Reward:121
# Actions Taken:172
# -----Episode: [14818/15000]-----
# Reward:140
# Actions Taken:191
# -----Episode: [14819/15000]-----
# Reward:253
# Actions Taken:304
# -----Episode: [14820/15000]-----
# Reward:196
# Actions Taken:247
# -----Episode: [14821/15000]-----
# Reward:199
# Actions Taken:250
# -----Episode: [14822/15000]-----
# Reward:165
# Actions Taken:216
# -----Episode: [14823/15000]-----
# Reward:181
# Actions Taken:232
# -----Episode: [14824/15000]-----
# Reward:164
# Actions Taken:215
# -----Episode: [14825/15000]-----
# Reward:164
# Actions Taken:215
# -----Episode: [14826/15000]-----
# Reward:25
# Actions Taken:76
# -----Episode: [14827/15000]-----
# Reward:207
# Actions Taken:258
# -----Episode: [14828/15000]-----
# Reward:148
# Actions Taken:199
# -----Episode: [14829/15000]-----
# Reward:257
# Actions Taken:308
# -----Episode: [14830/15000]-----
# Reward:258
# Actions Taken:309
# -----Episode: [14831/15000]-----
# Reward:177
# Actions Taken:228
# -----Episode: [14832/15000]-----
# Reward:195
# Actions Taken:246
# -----Episode: [14833/15000]-----
# Reward:129
# Actions Taken:180
# -----Episode: [14834/15000]-----
# Reward:142
# Actions Taken:193
# -----Episode: [14835/15000]-----
# Reward:125
# Actions Taken:176
# -----Episode: [14836/15000]-----
# Reward:190
# Actions Taken:241
# -----Episode: [14837/15000]-----
# Reward:206
# Actions Taken:257
# -----Episode: [14838/15000]-----
# Reward:162
# Actions Taken:213
# -----Episode: [14839/15000]-----
# Reward:242
# Actions Taken:293
# -----Episode: [14840/15000]-----
# Reward:201
# Actions Taken:252
# -----Episode: [14841/15000]-----
# Reward:221
# Actions Taken:272
# -----Episode: [14842/15000]-----
# Reward:177
# Actions Taken:228
# -----Episode: [14843/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [14844/15000]-----
# Reward:133
# Actions Taken:184
# -----Episode: [14845/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [14846/15000]-----
# Reward:156
# Actions Taken:207
# -----Episode: [14847/15000]-----
# Reward:153
# Actions Taken:204
# -----Episode: [14848/15000]-----
# Reward:115
# Actions Taken:166
# -----Episode: [14849/15000]-----
# Reward:63
# Actions Taken:114
# -----Episode: [14850/15000]-----
# Reward:193
# Actions Taken:244
# -----Episode: [14851/15000]-----
# Reward:56
# Actions Taken:107
# -----Episode: [14852/15000]-----
# Reward:50
# Actions Taken:101
# -----Episode: [14853/15000]-----
# Reward:39
# Actions Taken:90
# -----Episode: [14854/15000]-----
# Reward:216
# Actions Taken:267
# -----Episode: [14855/15000]-----
# Reward:179
# Actions Taken:230
# -----Episode: [14856/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [14857/15000]-----
# Reward:144
# Actions Taken:195
# -----Episode: [14858/15000]-----
# Reward:82
# Actions Taken:133
# -----Episode: [14859/15000]-----
# Reward:154
# Actions Taken:205
# -----Episode: [14860/15000]-----
# Reward:150
# Actions Taken:201
# -----Episode: [14861/15000]-----
# Reward:180
# Actions Taken:231
# -----Episode: [14862/15000]-----
# Reward:210
# Actions Taken:261
# -----Episode: [14863/15000]-----
# Reward:81
# Actions Taken:132
# -----Episode: [14864/15000]-----
# Reward:138
# Actions Taken:189
# -----Episode: [14865/15000]-----
# Reward:212
# Actions Taken:263
# -----Episode: [14866/15000]-----
# Reward:63
# Actions Taken:114
# -----Episode: [14867/15000]-----
# Reward:124
# Actions Taken:175
# -----Episode: [14868/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [14869/15000]-----
# Reward:143
# Actions Taken:194
# -----Episode: [14870/15000]-----
# Reward:146
# Actions Taken:197
# -----Episode: [14871/15000]-----
# Reward:83
# Actions Taken:134
# -----Episode: [14872/15000]-----
# Reward:78
# Actions Taken:129
# -----Episode: [14873/15000]-----
# Reward:197
# Actions Taken:248
# -----Episode: [14874/15000]-----
# Reward:69
# Actions Taken:120
# -----Episode: [14875/15000]-----
# Reward:197
# Actions Taken:248
# -----Episode: [14876/15000]-----
# Reward:174
# Actions Taken:225
# -----Episode: [14877/15000]-----
# Reward:174
# Actions Taken:225
# -----Episode: [14878/15000]-----
# Reward:158
# Actions Taken:209
# -----Episode: [14879/15000]-----
# Reward:78
# Actions Taken:129
# -----Episode: [14880/15000]-----
# Reward:213
# Actions Taken:264
# -----Episode: [14881/15000]-----
# Reward:202
# Actions Taken:253
# -----Episode: [14882/15000]-----
# Reward:29
# Actions Taken:80
# -----Episode: [14883/15000]-----
# Reward:174
# Actions Taken:225
# -----Episode: [14884/15000]-----
# Reward:132
# Actions Taken:183
# -----Episode: [14885/15000]-----
# Reward:148
# Actions Taken:199
# -----Episode: [14886/15000]-----
# Reward:132
# Actions Taken:183
# -----Episode: [14887/15000]-----
# Reward:213
# Actions Taken:264
# -----Episode: [14888/15000]-----
# Reward:237
# Actions Taken:288
# -----Episode: [14889/15000]-----
# Reward:227
# Actions Taken:278
# -----Episode: [14890/15000]-----
# Reward:166
# Actions Taken:217
# -----Episode: [14891/15000]-----
# Reward:245
# Actions Taken:296
# -----Episode: [14892/15000]-----
# Reward:156
# Actions Taken:207
# -----Episode: [14893/15000]-----
# Reward:167
# Actions Taken:218
# -----Episode: [14894/15000]-----
# Reward:121
# Actions Taken:172
# -----Episode: [14895/15000]-----
# Reward:171
# Actions Taken:222
# -----Episode: [14896/15000]-----
# Reward:59
# Actions Taken:110
# -----Episode: [14897/15000]-----
# Reward:202
# Actions Taken:253
# -----Episode: [14898/15000]-----
# Reward:169
# Actions Taken:220
# -----Episode: [14899/15000]-----
# Reward:132
# Actions Taken:183
# -----Episode: [14900/15000]-----
# Reward:137
# Actions Taken:188
# -----Episode: [14901/15000]-----
# Reward:272
# Actions Taken:323
# -----Episode: [14902/15000]-----
# Reward:201
# Actions Taken:252
# -----Episode: [14903/15000]-----
# Reward:129
# Actions Taken:180
# -----Episode: [14904/15000]-----
# Reward:192
# Actions Taken:243
# -----Episode: [14905/15000]-----
# Reward:196
# Actions Taken:247
# -----Episode: [14906/15000]-----
# Reward:80
# Actions Taken:131
# -----Episode: [14907/15000]-----
# Reward:238
# Actions Taken:289
# -----Episode: [14908/15000]-----
# Reward:46
# Actions Taken:97
# -----Episode: [14909/15000]-----
# Reward:182
# Actions Taken:233
# -----Episode: [14910/15000]-----
# Reward:155
# Actions Taken:206
# -----Episode: [14911/15000]-----
# Reward:190
# Actions Taken:241
# -----Episode: [14912/15000]-----
# Reward:110
# Actions Taken:161
# -----Episode: [14913/15000]-----
# Reward:201
# Actions Taken:252
# -----Episode: [14914/15000]-----
# Reward:160
# Actions Taken:211
# -----Episode: [14915/15000]-----
# Reward:156
# Actions Taken:207
# -----Episode: [14916/15000]-----
# Reward:143
# Actions Taken:194
# -----Episode: [14917/15000]-----
# Reward:204
# Actions Taken:255
# -----Episode: [14918/15000]-----
# Reward:168
# Actions Taken:219
# -----Episode: [14919/15000]-----
# Reward:217
# Actions Taken:268
# -----Episode: [14920/15000]-----
# Reward:202
# Actions Taken:253
# -----Episode: [14921/15000]-----
# Reward:129
# Actions Taken:180
# -----Episode: [14922/15000]-----
# Reward:66
# Actions Taken:117
# -----Episode: [14923/15000]-----
# Reward:237
# Actions Taken:288
# -----Episode: [14924/15000]-----
# Reward:147
# Actions Taken:198
# -----Episode: [14925/15000]-----
# Reward:134
# Actions Taken:185
# -----Episode: [14926/15000]-----
# Reward:132
# Actions Taken:183
# -----Episode: [14927/15000]-----
# Reward:223
# Actions Taken:274
# -----Episode: [14928/15000]-----
# Reward:64
# Actions Taken:115
# -----Episode: [14929/15000]-----
# Reward:285
# Actions Taken:336
# -----Episode: [14930/15000]-----
# Reward:43
# Actions Taken:94
# -----Episode: [14931/15000]-----
# Reward:125
# Actions Taken:176
# -----Episode: [14932/15000]-----
# Reward:131
# Actions Taken:182
# -----Episode: [14933/15000]-----
# Reward:77
# Actions Taken:128
# -----Episode: [14934/15000]-----
# Reward:164
# Actions Taken:215
# -----Episode: [14935/15000]-----
# Reward:215
# Actions Taken:266
# -----Episode: [14936/15000]-----
# Reward:148
# Actions Taken:199
# -----Episode: [14937/15000]-----
# Reward:126
# Actions Taken:177
# -----Episode: [14938/15000]-----
# Reward:33
# Actions Taken:84
# -----Episode: [14939/15000]-----
# Reward:130
# Actions Taken:181
# -----Episode: [14940/15000]-----
# Reward:44
# Actions Taken:95
# -----Episode: [14941/15000]-----
# Reward:52
# Actions Taken:103
# -----Episode: [14942/15000]-----
# Reward:212
# Actions Taken:263
# -----Episode: [14943/15000]-----
# Reward:50
# Actions Taken:101
# -----Episode: [14944/15000]-----
# Reward:206
# Actions Taken:257
# -----Episode: [14945/15000]-----
# Reward:155
# Actions Taken:206
# -----Episode: [14946/15000]-----
# Reward:34
# Actions Taken:85
# -----Episode: [14947/15000]-----
# Reward:178
# Actions Taken:229
# -----Episode: [14948/15000]-----
# Reward:310
# Actions Taken:361
# -----Episode: [14949/15000]-----
# Reward:151
# Actions Taken:202
# -----Episode: [14950/15000]-----
# Reward:167
# Actions Taken:218
# -----Episode: [14951/15000]-----
# Reward:16
# Actions Taken:67
# -----Episode: [14952/15000]-----
# Reward:143
# Actions Taken:194
# -----Episode: [14953/15000]-----
# Reward:163
# Actions Taken:214
# -----Episode: [14954/15000]-----
# Reward:42
# Actions Taken:93
# -----Episode: [14955/15000]-----
# Reward:191
# Actions Taken:242
# -----Episode: [14956/15000]-----
# Reward:175
# Actions Taken:226
# -----Episode: [14957/15000]-----
# Reward:174
# Actions Taken:225
# -----Episode: [14958/15000]-----
# Reward:126
# Actions Taken:177
# -----Episode: [14959/15000]-----
# Reward:145
# Actions Taken:196
# -----Episode: [14960/15000]-----
# Reward:87
# Actions Taken:138
# -----Episode: [14961/15000]-----
# Reward:136
# Actions Taken:187
# -----Episode: [14962/15000]-----
# Reward:40
# Actions Taken:91
# -----Episode: [14963/15000]-----
# Reward:154
# Actions Taken:205
# -----Episode: [14964/15000]-----
# Reward:25
# Actions Taken:76
# -----Episode: [14965/15000]-----
# Reward:181
# Actions Taken:232
# -----Episode: [14966/15000]-----
# Reward:159
# Actions Taken:210
# -----Episode: [14967/15000]-----
# Reward:183
# Actions Taken:234
# -----Episode: [14968/15000]-----
# Reward:173
# Actions Taken:224
# -----Episode: [14969/15000]-----
# Reward:60
# Actions Taken:111
# -----Episode: [14970/15000]-----
# Reward:187
# Actions Taken:238
# -----Episode: [14971/15000]-----
# Reward:113
# Actions Taken:164
# -----Episode: [14972/15000]-----
# Reward:30
# Actions Taken:81
# -----Episode: [14973/15000]-----
# Reward:15
# Actions Taken:66
# -----Episode: [14974/15000]-----
# Reward:229
# Actions Taken:280
# -----Episode: [14975/15000]-----
# Reward:175
# Actions Taken:226
# -----Episode: [14976/15000]-----
# Reward:85
# Actions Taken:136
# -----Episode: [14977/15000]-----
# Reward:218
# Actions Taken:269
# -----Episode: [14978/15000]-----
# Reward:201
# Actions Taken:252
# -----Episode: [14979/15000]-----
# Reward:151
# Actions Taken:202
# -----Episode: [14980/15000]-----
# Reward:153
# Actions Taken:204
# -----Episode: [14981/15000]-----
# Reward:147
# Actions Taken:198
# -----Episode: [14982/15000]-----
# Reward:137
# Actions Taken:188
# -----Episode: [14983/15000]-----
# Reward:100
# Actions Taken:151
# -----Episode: [14984/15000]-----
# Reward:228
# Actions Taken:279
# -----Episode: [14985/15000]-----
# Reward:198
# Actions Taken:249
# -----Episode: [14986/15000]-----
# Reward:35
# Actions Taken:86
# -----Episode: [14987/15000]-----
# Reward:229
# Actions Taken:280
# -----Episode: [14988/15000]-----
# Reward:195
# Actions Taken:246
# -----Episode: [14989/15000]-----
# Reward:178
# Actions Taken:229
# -----Episode: [14990/15000]-----
# Reward:248
# Actions Taken:299
# -----Episode: [14991/15000]-----
# Reward:231
# Actions Taken:282
# -----Episode: [14992/15000]-----
# Reward:36
# Actions Taken:87
# -----Episode: [14993/15000]-----
# Reward:153
# Actions Taken:204
# -----Episode: [14994/15000]-----
# Reward:67
# Actions Taken:118
# -----Episode: [14995/15000]-----
# Reward:74
# Actions Taken:125
# -----Episode: [14996/15000]-----
# Reward:24
# Actions Taken:75
# -----Episode: [14997/15000]-----
# Reward:88
# Actions Taken:139
# -----Episode: [14998/15000]-----
# Reward:26
# Actions Taken:77
# -----Episode: [14999/15000]-----
# Reward:64
# Actions Taken:115
# -----Episode: [15000/15000]-----
# Reward:177
# Actions Taken:228

# %%
plt.figure(figsize=(10,5))
plt.plot(rewards_history, label="Reward per Episode")

# Moving average (window=5)
if len(rewards_history) >= 5:
    avg5 = np.convolve(rewards_history, np.ones(5)/5, mode='valid')
    plt.plot(range(4, len(rewards_history)), avg5, label="5-Episode Moving Avg", color='orange')

# Global mean (cumulative average)
global_mean = np.cumsum(rewards_history) / (np.arange(len(rewards_history)) + 1)
plt.plot(global_mean, label="Cumulative Average", color='red', linewidth=2)

plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Reward per Episode (Double DQN)")
plt.grid()
plt.legend()
plt.show()
