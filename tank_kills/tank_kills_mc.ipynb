# %%
from tank_kills_v2 import TankKills
import random
from pynput.keyboard import Controller,Key
import time
import pygame
# Out:
# pygame 2.2.0 (SDL 2.0.22, Python 3.10.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
ins = [
    Key.up,
    Key.right,
    Key.down,
    Key.left
    ]

# %%
keyboard = Controller()
game_1 = TankKills(600,600)

# %%
running = True
while running:
    move = random.randint(0,3)
    running,score,pp,ep = game_1.play()
    keyboard.press(ins[move])
    keyboard.release(ins[move])
    print(running,score,pp,ep)
if not running:
    pygame.display.quit()
# Out:
# True 0 [300, 400] [463.3, 100.2]
# KEY: RIGHT
# True 0 [300, 400] [463.6, 100.4]
# KEY: LEFT
# True 0 [300, 400] [463.90000000000003, 100.60000000000001]
# KEY: RIGHT
# True 0 [300, 400] [464.20000000000005, 100.80000000000001]
# KEY: LEFT
# True 0 [300, 400] [464.50000000000006, 101.00000000000001]
# KEY: RIGHT
# True 0 [300, 400] [464.80000000000007, 101.20000000000002]
# KEY: RIGHT
# True 0 [300, 400] [465.1000000000001, 101.40000000000002]
# KEY: UP
# True 0 [300, 390] [465.4000000000001, 101.60000000000002]
# KEY: UP
# True 0 [300, 380] [465.7000000000001, 101.80000000000003]
# KEY: LEFT
# True 0 [300, 380] [466.0000000000001, 102.00000000000003]
# KEY: LEFT
# True 0 [300, 380] [466.3000000000001, 102.20000000000003]
# KEY: UP
# True 0 [300, 370] [466.60000000000014, 102.40000000000003]
# KEY: LEFT
# True 0 [300, 370] [466.90000000000015, 102.60000000000004]
# KEY: RIGHT
# True 0 [300, 370] [467.20000000000016, 102.80000000000004]
# KEY: UP
# True 0 [300, 360] [467.50000000000017, 103.00000000000004]
# KEY: LEFT
# True 0 [300, 360] [467.8000000000002, 103.20000000000005]
# KEY: UP
# True 0 [300, 350] [468.1000000000002, 103.40000000000005]
# KEY: LEFT
# True 0 [300, 350] [468.4000000000002, 103.60000000000005]
# KEY: RIGHT
# True 0 [300, 350] [468.7000000000002, 103.80000000000005]
# KEY: DOWN
# True 0 [300, 370] [469.0000000000002, 104.00000000000006]
# KEY: RIGHT
# True 0 [300, 370] [469.30000000000024, 104.20000000000006]
# KEY: RIGHT
# True 0 [300, 370] [469.60000000000025, 104.40000000000006]
# KEY: UP
# True 0 [300, 360] [469.90000000000026, 104.60000000000007]
# KEY: RIGHT
# True 0 [300, 360] [470.2000000000003, 104.80000000000007]
# KEY: UP
# True 0 [300, 350] [470.5000000000003, 105.00000000000007]
# KEY: DOWN
# True 0 [300, 370] [470.8000000000003, 105.20000000000007]
# KEY: LEFT
# True 0 [300, 370] [471.1000000000003, 105.40000000000008]
# KEY: UP
# True 0 [300, 360] [471.4000000000003, 105.60000000000008]
# KEY: RIGHT
# True 0 [300, 360] [471.70000000000033, 105.80000000000008]
# KEY: UP
# True 0 [300, 350] [472.00000000000034, 106.00000000000009]
# KEY: RIGHT
# True 0 [300, 350] [472.30000000000035, 106.20000000000009]
# KEY: LEFT
# True 0 [300, 350] [472.60000000000036, 106.40000000000009]
# KEY: UP
# True 0 [300, 340] [472.9000000000004, 106.6000000000001]
# KEY: RIGHT
# True 0 [300, 340] [473.2000000000004, 106.8000000000001]
# KEY: RIGHT
# True 0 [300, 340] [473.5000000000004, 107.0000000000001]
# KEY: RIGHT
# True 0 [300, 340] [473.8000000000004, 107.2000000000001]
# KEY: LEFT
# True 0 [300, 340] [474.1000000000004, 107.4000000000001]
# KEY: UP
# True 0 [300, 330] [474.40000000000043, 107.60000000000011]
# KEY: DOWN
# True 0 [300, 350] [474.70000000000044, 107.80000000000011]
# KEY: RIGHT
# True 0 [300, 350] [475.00000000000045, 108.00000000000011]
# KEY: DOWN
# True 0 [300, 370] [475.30000000000047, 108.20000000000012]
# KEY: RIGHT
# True 0 [300, 370] [475.6000000000005, 108.40000000000012]
# KEY: LEFT
# True 0 [300, 370] [475.9000000000005, 108.60000000000012]
# KEY: DOWN
# True 0 [300, 390] [476.2000000000005, 108.80000000000013]
# KEY: LEFT
# True 0 [300, 390] [476.5000000000005, 109.00000000000013]
# KEY: LEFT
# True 0 [300, 390] [476.8000000000005, 109.20000000000013]
# KEY: LEFT
# True 0 [300, 390] [477.10000000000053, 109.40000000000013]
# KEY: DOWN
# True 0 [300, 410] [477.40000000000055, 109.60000000000014]
# KEY: RIGHT
# True 0 [300, 410] [477.70000000000056, 109.80000000000014]
# KEY: LEFT
# True 0 [300, 410] [478.00000000000057, 110.00000000000014]
# KEY: LEFT
# True 0 [300, 410] [478.3000000000006, 110.20000000000014]
# KEY: LEFT
# True 0 [300, 410] [478.6000000000006, 110.40000000000015]
# KEY: DOWN
# True 0 [300, 430] [478.9000000000006, 110.60000000000015]
# KEY: LEFT
# True 0 [300, 430] [479.2000000000006, 110.80000000000015]
# KEY: DOWN
# True 0 [300, 450] [479.5000000000006, 111.00000000000016]
# KEY: UP
# True 0 [300, 440] [479.80000000000064, 111.20000000000016]
# KEY: LEFT
# True 0 [300, 440] [480.10000000000065, 111.40000000000016]
# KEY: RIGHT
# True 0 [300, 440] [480.40000000000066, 111.60000000000016]
# KEY: UP
# True 0 [300, 430] [480.70000000000067, 111.80000000000017]
# KEY: RIGHT
# True 0 [300, 430] [481.0000000000007, 112.00000000000017]
# KEY: LEFT
# True 0 [300, 430] [481.3000000000007, 112.20000000000017]
# KEY: UP
# True 0 [300, 420] [481.6000000000007, 112.40000000000018]
# KEY: LEFT
# True 0 [300, 420] [481.9000000000007, 112.60000000000018]
# KEY: LEFT
# True 0 [300, 420] [482.2000000000007, 112.80000000000018]
# KEY: RIGHT
# True 0 [300, 420] [482.50000000000074, 113.00000000000018]
# KEY: RIGHT
# True 0 [300, 420] [482.80000000000075, 113.20000000000019]
# KEY: RIGHT
# True 0 [300, 420] [483.10000000000076, 113.40000000000019]
# KEY: LEFT
# True 0 [300, 420] [483.4000000000008, 113.6000000000002]
# KEY: LEFT
# True 0 [300, 420] [483.7000000000008, 113.8000000000002]
# KEY: UP
# True 0 [300, 410] [484.0000000000008, 114.0000000000002]
# KEY: RIGHT
# True 0 [300, 410] [484.3000000000008, 114.2000000000002]
# KEY: DOWN
# True 0 [300, 430] [484.6000000000008, 114.4000000000002]
# KEY: LEFT
# True 0 [300, 430] [484.90000000000083, 114.60000000000021]
# KEY: LEFT
# True 0 [300, 430] [485.20000000000084, 114.80000000000021]
# KEY: DOWN
# True 0 [300, 450] [485.50000000000085, 115.00000000000021]
# KEY: RIGHT
# True 0 [300, 450] [485.80000000000086, 115.20000000000022]
# KEY: RIGHT
# True 0 [300, 450] [486.1000000000009, 115.40000000000022]
# KEY: RIGHT
# True 0 [300, 450] [486.4000000000009, 115.60000000000022]
# KEY: LEFT
# True 0 [300, 450] [486.7000000000009, 115.80000000000022]
# KEY: DOWN
# True 0 [300, 470] [487.0000000000009, 116.00000000000023]
# KEY: UP
# True 0 [300, 460] [487.3000000000009, 116.20000000000023]
# KEY: RIGHT
# True 0 [300, 460] [487.60000000000093, 116.40000000000023]
# KEY: UP
# True 0 [300, 450] [487.90000000000094, 116.60000000000024]
# KEY: LEFT
# True 0 [300, 450] [488.20000000000095, 116.80000000000024]
# KEY: RIGHT
# True 0 [300, 450] [488.50000000000097, 117.00000000000024]
# KEY: RIGHT
# True 0 [300, 450] [488.800000000001, 117.20000000000024]
# KEY: DOWN
# True 0 [300, 470] [489.100000000001, 117.40000000000025]
# KEY: RIGHT
# True 0 [300, 470] [489.400000000001, 117.60000000000025]
# KEY: LEFT
# True 0 [300, 470] [489.700000000001, 117.80000000000025]
# KEY: LEFT
# True 0 [300, 470] [490.000000000001, 118.00000000000026]
# KEY: LEFT
# True 0 [300, 470] [490.30000000000103, 118.20000000000026]
# KEY: DOWN
# True 0 [300, 490] [490.60000000000105, 118.40000000000026]
# KEY: UP
# True 0 [300, 480] [490.90000000000106, 118.60000000000026]
# KEY: RIGHT
# True 0 [300, 480] [491.20000000000107, 118.80000000000027]
# KEY: LEFT
# True 0 [300, 480] [491.5000000000011, 119.00000000000027]
# KEY: DOWN
# True 0 [300, 500] [491.8000000000011, 119.20000000000027]
# KEY: UP
# True 0 [300, 490] [492.1000000000011, 119.40000000000028]
# KEY: LEFT
# True 0 [300, 490] [492.4000000000011, 119.60000000000028]
# KEY: DOWN
# True 0 [300, 510] [492.7000000000011, 119.80000000000028]
# KEY: LEFT
# True 0 [300, 510] [493.00000000000114, 120.00000000000028]
# KEY: UP
# True 0 [300, 500] [493.30000000000115, 120.20000000000029]
# KEY: RIGHT
# True 0 [300, 500] [493.60000000000116, 120.40000000000029]
# KEY: DOWN
# True 0 [300, 520] [493.90000000000117, 120.60000000000029]
# KEY: RIGHT
# True 0 [300, 520] [494.2000000000012, 120.8000000000003]
# KEY: UP
# True 0 [300, 510] [494.5000000000012, 121.0000000000003]
# KEY: RIGHT
# True 0 [300, 510] [494.8000000000012, 121.2000000000003]
# KEY: UP
# True 0 [300, 500] [495.1000000000012, 121.4000000000003]
# KEY: LEFT
# True 0 [300, 500] [495.4000000000012, 121.6000000000003]
# KEY: RIGHT
# True 0 [300, 500] [495.70000000000124, 121.80000000000031]
# KEY: RIGHT
# True 0 [300, 500] [496.00000000000125, 122.00000000000031]
# KEY: LEFT
# True 0 [300, 500] [496.30000000000126, 122.20000000000032]
# KEY: DOWN
# True 0 [300, 520] [496.6000000000013, 122.40000000000032]
# KEY: UP
# True 0 [300, 510] [496.9000000000013, 122.60000000000032]
# KEY: UP
# True 0 [300, 500] [497.2000000000013, 122.80000000000032]
# KEY: DOWN
# True 0 [300, 520] [497.5000000000013, 123.00000000000033]
# KEY: UP
# True 0 [300, 510] [497.8000000000013, 123.20000000000033]
# KEY: UP
# True 0 [300, 500] [498.10000000000133, 123.40000000000033]
# KEY: DOWN
# True 0 [300, 520] [498.40000000000134, 123.60000000000034]
# KEY: UP
# True 0 [300, 510] [498.70000000000135, 123.80000000000034]
# KEY: LEFT
# True 0 [300, 510] [499.00000000000136, 124.00000000000034]
# KEY: RIGHT
# True 0 [300, 510] [499.3000000000014, 124.20000000000034]
# KEY: LEFT
# True 0 [300, 510] [499.6000000000014, 124.40000000000035]
# KEY: RIGHT
# True 0 [300, 510] [499.9000000000014, 124.60000000000035]
# KEY: UP
# True 0 [300, 500] [500.2000000000014, 124.80000000000035]
# KEY: LEFT
# True 0 [300, 500] [500.5000000000014, 125.00000000000036]
# KEY: LEFT
# True 0 [300, 500] [500.80000000000143, 125.20000000000036]
# KEY: DOWN
# True 0 [300, 520] [501.10000000000144, 125.40000000000036]
# KEY: RIGHT
# True 0 [300, 520] [501.40000000000146, 125.60000000000036]
# KEY: LEFT
# True 0 [300, 520] [501.70000000000147, 125.80000000000037]
# KEY: RIGHT
# True 0 [300, 520] [502.0000000000015, 126.00000000000037]
# KEY: UP
# True 0 [300, 510] [502.3000000000015, 126.20000000000037]
# KEY: UP
# True 0 [300, 500] [502.6000000000015, 126.40000000000038]
# KEY: RIGHT
# True 0 [300, 500] [502.9000000000015, 126.60000000000038]
# KEY: DOWN
# True 0 [300, 520] [503.2000000000015, 126.80000000000038]
# KEY: RIGHT
# True 0 [300, 520] [503.50000000000153, 127.00000000000038]
# KEY: UP
# True 0 [300, 510] [503.80000000000155, 127.20000000000039]
# KEY: DOWN
# True 0 [300, 530] [504.10000000000156, 127.40000000000039]
# KEY: LEFT
# True 0 [300, 530] [504.40000000000157, 127.60000000000039]
# KEY: RIGHT
# True 0 [300, 530] [504.7000000000016, 127.8000000000004]
# KEY: RIGHT
# True 0 [300, 530] [505.0000000000016, 128.0000000000004]
# KEY: UP
# True 0 [300, 520] [505.3000000000016, 128.2000000000004]
# KEY: LEFT
# True 0 [300, 520] [505.6000000000016, 128.40000000000038]
# KEY: RIGHT
# True 0 [300, 520] [505.9000000000016, 128.60000000000036]
# KEY: RIGHT
# True 0 [300, 520] [506.20000000000164, 128.80000000000035]
# KEY: LEFT
# True 0 [300, 520] [506.50000000000165, 129.00000000000034]
# KEY: UP
# True 0 [300, 510] [506.80000000000166, 129.20000000000033]
# KEY: DOWN
# True 0 [300, 530] [507.10000000000167, 129.40000000000032]
# KEY: DOWN
# True 0 [300, 550] [507.4000000000017, 129.6000000000003]
# KEY: DOWN
# True 0 [300, 570] [507.7000000000017, 129.8000000000003]
# KEY: RIGHT
# True 0 [300, 570] [508.0000000000017, 130.00000000000028]
# KEY: RIGHT
# True 0 [300, 570] [508.3000000000017, 130.20000000000027]
# KEY: UP
# True 0 [300, 560] [508.6000000000017, 130.40000000000026]
# KEY: UP
# True 0 [300, 550] [508.90000000000174, 130.60000000000025]
# KEY: LEFT
# True 0 [300, 550] [509.20000000000175, 130.80000000000024]
# KEY: RIGHT
# True 0 [300, 550] [509.50000000000176, 131.00000000000023]
# KEY: RIGHT
# True 0 [300, 550] [509.8000000000018, 131.20000000000022]
# KEY: RIGHT
# True 0 [300, 550] [510.1000000000018, 131.4000000000002]
# KEY: RIGHT
# True 0 [300, 550] [510.4000000000018, 131.6000000000002]
# KEY: RIGHT
# True 0 [300, 550] [510.7000000000018, 131.80000000000018]
# KEY: DOWN
# True 0 [300, 570] [511.0000000000018, 132.00000000000017]
# KEY: UP
# True 0 [300, 560] [511.30000000000183, 132.20000000000016]
# KEY: LEFT
# True 0 [300, 560] [511.60000000000184, 132.40000000000015]
# KEY: UP
# True 0 [300, 550] [511.90000000000185, 132.60000000000014]
# KEY: UP
# True 0 [300, 540] [512.2000000000019, 132.80000000000013]
# KEY: DOWN
# True 0 [300, 560] [512.5000000000018, 133.0000000000001]
# KEY: DOWN
# True 0 [300, 580] [512.8000000000018, 133.2000000000001]
# KEY: UP
# True 0 [300, 570] [513.1000000000017, 133.4000000000001]
# KEY: UP
# True 0 [300, 560] [513.4000000000017, 133.60000000000008]
# KEY: RIGHT
# True 0 [300, 560] [513.7000000000016, 133.80000000000007]
# KEY: RIGHT
# True 0 [300, 560] [514.0000000000016, 134.00000000000006]
# KEY: DOWN
# True 0 [300, 580] [514.3000000000015, 134.20000000000005]
# KEY: DOWN
# True 0 [300, 580] [514.6000000000015, 134.40000000000003]
# KEY: LEFT
# True 0 [300, 580] [514.9000000000015, 134.60000000000002]
# KEY: RIGHT
# True 0 [300, 580] [515.2000000000014, 134.8]
# KEY: LEFT
# True 0 [300, 580] [515.5000000000014, 135.0]
# KEY: RIGHT
# True 0 [300, 580] [515.8000000000013, 135.2]
# KEY: DOWN
# True 0 [300, 580] [516.1000000000013, 135.39999999999998]
# KEY: RIGHT
# True 0 [300, 580] [516.4000000000012, 135.59999999999997]
# KEY: DOWN
# True 0 [300, 580] [516.7000000000012, 135.79999999999995]
# KEY: DOWN
# True 0 [300, 580] [517.0000000000011, 135.99999999999994]
# KEY: UP
# True 0 [300, 570] [517.3000000000011, 136.19999999999993]
# KEY: RIGHT
# True 0 [300, 570] [517.600000000001, 136.39999999999992]
# KEY: UP
# True 0 [300, 560] [517.900000000001, 136.5999999999999]
# KEY: DOWN
# True 0 [300, 580] [518.200000000001, 136.7999999999999]
# KEY: RIGHT
# True 0 [300, 580] [518.5000000000009, 136.9999999999999]
# KEY: UP
# True 0 [300, 570] [518.8000000000009, 137.19999999999987]
# KEY: DOWN
# True 0 [300, 580] [519.1000000000008, 137.39999999999986]
# KEY: DOWN
# True 0 [300, 580] [519.4000000000008, 137.59999999999985]
# KEY: DOWN
# True 0 [300, 580] [519.7000000000007, 137.79999999999984]
# KEY: UP
# True 0 [300, 570] [520.0000000000007, 137.99999999999983]
# KEY: UP
# True 0 [300, 560] [520.3000000000006, 138.19999999999982]
# KEY: RIGHT
# True 0 [300, 560] [520.6000000000006, 138.3999999999998]
# KEY: DOWN
# True 0 [300, 580] [520.9000000000005, 138.5999999999998]
# KEY: DOWN
# True 0 [300, 580] [521.2000000000005, 138.79999999999978]
# KEY: LEFT
# True 0 [300, 580] [521.5000000000005, 138.99999999999977]
# KEY: RIGHT
# True 0 [300, 580] [521.8000000000004, 139.19999999999976]
# KEY: RIGHT
# True 0 [300, 580] [522.1000000000004, 139.39999999999975]
# KEY: DOWN
# True 0 [300, 580] [522.4000000000003, 139.59999999999974]
# KEY: RIGHT
# True 0 [300, 580] [522.7000000000003, 139.79999999999973]
# KEY: RIGHT
# True 0 [300, 580] [523.0000000000002, 139.99999999999972]
# KEY: LEFT
# True 0 [300, 580] [523.3000000000002, 140.1999999999997]
# KEY: LEFT
# True 0 [300, 580] [523.6000000000001, 140.3999999999997]
# KEY: RIGHT
# True 0 [300, 580] [523.9000000000001, 140.59999999999968]
# KEY: LEFT
# True 0 [300, 580] [524.2, 140.79999999999967]
# KEY: RIGHT
# True 0 [300, 580] [524.5, 140.99999999999966]
# KEY: UP
# True 0 [300, 570] [524.8, 141.19999999999965]
# KEY: RIGHT
# True 0 [300, 570] [525.0999999999999, 141.39999999999964]
# KEY: RIGHT
# True 0 [300, 570] [525.3999999999999, 141.59999999999962]
# KEY: LEFT
# True 0 [300, 570] [525.6999999999998, 141.7999999999996]
# KEY: RIGHT
# True 0 [300, 570] [525.9999999999998, 141.9999999999996]
# KEY: DOWN
# True 0 [300, 580] [526.2999999999997, 142.1999999999996]
# KEY: DOWN
# True 0 [300, 580] [526.5999999999997, 142.39999999999958]
# KEY: DOWN
# True 0 [300, 580] [526.8999999999996, 142.59999999999957]
# KEY: UP
# True 0 [300, 570] [527.1999999999996, 142.79999999999956]
# KEY: RIGHT
# True 0 [300, 570] [527.4999999999995, 142.99999999999955]
# KEY: DOWN
# True 0 [300, 580] [527.7999999999995, 143.19999999999953]
# KEY: LEFT
# True 0 [300, 580] [528.0999999999995, 143.39999999999952]
# KEY: DOWN
# True 0 [300, 580] [528.3999999999994, 143.5999999999995]
# KEY: DOWN
# True 0 [300, 580] [528.6999999999994, 143.7999999999995]
# KEY: DOWN
# True 0 [300, 580] [528.9999999999993, 143.9999999999995]
# KEY: DOWN
# True 0 [300, 580] [529.2999999999993, 144.19999999999948]
# KEY: DOWN
# True 0 [300, 580] [529.5999999999992, 144.39999999999947]
# KEY: DOWN
# True 0 [300, 580] [529.8999999999992, 144.59999999999945]
# KEY: RIGHT
# True 0 [300, 580] [530.1999999999991, 144.79999999999944]
# KEY: DOWN
# True 0 [300, 580] [530.4999999999991, 144.99999999999943]
# KEY: LEFT
# True 0 [300, 580] [530.799999999999, 145.19999999999942]
# KEY: UP
# True 0 [300, 570] [531.099999999999, 145.3999999999994]
# KEY: UP
# True 0 [300, 560] [531.399999999999, 145.5999999999994]
# KEY: RIGHT
# True 0 [300, 560] [531.6999999999989, 145.7999999999994]
# KEY: LEFT
# True 0 [300, 560] [531.9999999999989, 145.99999999999937]
# KEY: LEFT
# True 0 [300, 560] [532.2999999999988, 146.19999999999936]
# KEY: DOWN
# True 0 [300, 580] [532.5999999999988, 146.39999999999935]
# KEY: RIGHT
# True 0 [300, 580] [532.8999999999987, 146.59999999999934]
# KEY: UP
# True 0 [300, 570] [533.1999999999987, 146.79999999999933]
# KEY: DOWN
# True 0 [300, 580] [533.4999999999986, 146.99999999999932]
# KEY: LEFT
# True 0 [300, 580] [533.7999999999986, 147.1999999999993]
# KEY: LEFT
# True 0 [300, 580] [534.0999999999985, 147.3999999999993]
# KEY: LEFT
# True 0 [300, 580] [534.3999999999985, 147.59999999999928]
# KEY: RIGHT
# True 0 [300, 580] [534.6999999999985, 147.79999999999927]
# KEY: RIGHT
# True 0 [300, 580] [534.9999999999984, 147.99999999999926]
# KEY: DOWN
# True 0 [300, 580] [535.2999999999984, 148.19999999999925]
# KEY: UP
# True 0 [300, 570] [535.5999999999983, 148.39999999999924]
# KEY: UP
# True 0 [300, 560] [535.8999999999983, 148.59999999999923]
# KEY: LEFT
# True 0 [300, 560] [536.1999999999982, 148.79999999999922]
# KEY: LEFT
# True 0 [300, 560] [536.4999999999982, 148.9999999999992]
# KEY: LEFT
# True 0 [300, 560] [536.7999999999981, 149.1999999999992]
# KEY: LEFT
# True 0 [300, 560] [537.0999999999981, 149.39999999999918]
# KEY: DOWN
# True 0 [300, 580] [537.399999999998, 149.59999999999917]
# KEY: DOWN
# True 0 [300, 580] [537.699999999998, 149.79999999999916]
# KEY: RIGHT
# True 0 [300, 580] [537.999999999998, 149.99999999999915]
# KEY: RIGHT
# True 0 [300, 580] [538.2999999999979, 150.19999999999914]
# KEY: DOWN
# True 0 [300, 580] [538.5999999999979, 150.39999999999912]
# KEY: RIGHT
# True 0 [300, 580] [538.8999999999978, 150.5999999999991]
# KEY: RIGHT
# True 0 [300, 580] [539.1999999999978, 150.7999999999991]
# KEY: DOWN
# True 0 [300, 580] [539.4999999999977, 150.9999999999991]
# KEY: LEFT
# True 0 [300, 580] [539.7999999999977, 151.19999999999908]
# KEY: UP
# True 0 [300, 570] [540.0999999999976, 151.39999999999907]
# KEY: LEFT
# True 0 [300, 570] [540.3999999999976, 151.59999999999906]
# KEY: UP
# True 0 [300, 560] [540.6999999999975, 151.79999999999905]
# KEY: UP
# True 0 [300, 550] [540.9999999999975, 151.99999999999903]
# KEY: RIGHT
# True 0 [300, 550] [541.2999999999975, 152.19999999999902]
# KEY: DOWN
# True 0 [300, 570] [541.5999999999974, 152.399999999999]
# KEY: RIGHT
# True 0 [300, 570] [541.8999999999974, 152.599999999999]
# KEY: DOWN
# True 0 [300, 580] [542.1999999999973, 152.799999999999]
# KEY: LEFT
# True 0 [300, 580] [542.4999999999973, 152.99999999999898]
# KEY: LEFT
# True 0 [300, 580] [542.7999999999972, 153.19999999999897]
# KEY: UP
# True 0 [300, 570] [543.0999999999972, 153.39999999999895]
# KEY: UP
# True 0 [300, 560] [543.3999999999971, 153.59999999999894]
# KEY: LEFT
# True 0 [300, 560] [543.6999999999971, 153.79999999999893]
# KEY: UP
# True 0 [300, 550] [543.999999999997, 153.99999999999892]
# KEY: RIGHT
# True 0 [300, 550] [544.299999999997, 154.1999999999989]
# KEY: DOWN
# True 0 [300, 570] [544.599999999997, 154.3999999999989]
# KEY: RIGHT
# True 0 [300, 570] [544.8999999999969, 154.5999999999989]
# KEY: LEFT
# True 0 [300, 570] [545.1999999999969, 154.79999999999887]
# KEY: DOWN
# True 0 [300, 580] [545.4999999999968, 154.99999999999886]
# KEY: RIGHT
# True 0 [300, 580] [545.7999999999968, 155.19999999999885]
# KEY: RIGHT
# True 0 [300, 580] [546.0999999999967, 155.39999999999884]
# KEY: LEFT
# True 0 [300, 580] [546.3999999999967, 155.59999999999883]
# KEY: RIGHT
# True 0 [300, 580] [546.6999999999966, 155.79999999999882]
# KEY: UP
# True 0 [300, 570] [546.9999999999966, 155.9999999999988]
# KEY: UP
# True 0 [300, 560] [547.2999999999965, 156.1999999999988]
# KEY: RIGHT
# True 0 [300, 560] [547.5999999999965, 156.39999999999878]
# KEY: UP
# True 0 [300, 550] [547.8999999999965, 156.59999999999877]
# KEY: DOWN
# True 0 [300, 570] [548.1999999999964, 156.79999999999876]
# KEY: LEFT
# True 0 [300, 570] [548.4999999999964, 156.99999999999875]
# KEY: LEFT
# True 0 [300, 570] [548.7999999999963, 157.19999999999874]
# KEY: LEFT
# True 0 [300, 570] [549.0999999999963, 157.39999999999873]
# KEY: UP
# True 0 [300, 560] [549.3999999999962, 157.59999999999872]
# KEY: DOWN
# True 0 [300, 580] [549.6999999999962, 157.7999999999987]
# KEY: LEFT
# True 0 [300, 580] [549.9999999999961, 157.9999999999987]
# KEY: UP
# True 0 [300, 570] [550.2999999999961, 158.19999999999868]
# KEY: UP
# True 0 [300, 560] [550.599999999996, 158.39999999999867]
# KEY: DOWN
# True 0 [300, 580] [550.899999999996, 158.59999999999866]
# KEY: LEFT
# True 0 [300, 580] [551.199999999996, 158.79999999999865]
# KEY: RIGHT
# True 0 [300, 580] [551.4999999999959, 158.99999999999864]
# KEY: DOWN
# True 0 [300, 580] [551.7999999999959, 159.19999999999862]
# KEY: LEFT
# True 0 [300, 580] [552.0999999999958, 159.3999999999986]
# KEY: UP
# True 0 [300, 570] [552.3999999999958, 159.5999999999986]
# KEY: RIGHT
# True 0 [300, 570] [552.6999999999957, 159.7999999999986]
# KEY: LEFT
# True 0 [300, 570] [552.9999999999957, 159.99999999999858]
# KEY: RIGHT
# True 0 [300, 570] [553.2999999999956, 160.19999999999857]
# KEY: RIGHT
# True 0 [300, 570] [553.5999999999956, 160.39999999999856]
# KEY: RIGHT
# True 0 [300, 570] [553.8999999999955, 160.59999999999854]
# KEY: DOWN
# True 0 [300, 580] [554.1999999999955, 160.79999999999853]
# KEY: LEFT
# True 0 [300, 580] [554.4999999999955, 160.99999999999852]
# KEY: DOWN
# True 0 [300, 580] [554.7999999999954, 161.1999999999985]
# KEY: UP
# True 0 [300, 570] [555.0999999999954, 161.3999999999985]
# KEY: RIGHT
# True 0 [300, 570] [555.3999999999953, 161.5999999999985]
# KEY: LEFT
# True 0 [300, 570] [555.6999999999953, 161.79999999999848]
# KEY: LEFT
# True 0 [300, 570] [555.9999999999952, 161.99999999999847]
# KEY: LEFT
# True 0 [300, 570] [556.2999999999952, 162.19999999999845]
# KEY: LEFT
# True 0 [300, 570] [556.5999999999951, 162.39999999999844]
# KEY: LEFT
# True 0 [300, 570] [556.8999999999951, 162.59999999999843]
# KEY: RIGHT
# True 0 [300, 570] [557.199999999995, 162.79999999999842]
# KEY: UP
# True 0 [300, 560] [557.499999999995, 162.9999999999984]
# KEY: RIGHT
# True 0 [300, 560] [557.799999999995, 163.1999999999984]
# KEY: DOWN
# True 0 [300, 580] [558.0999999999949, 163.39999999999839]
# KEY: DOWN
# True 0 [300, 580] [558.3999999999949, 163.59999999999837]
# KEY: RIGHT
# True 0 [300, 580] [558.6999999999948, 163.79999999999836]
# KEY: UP
# True 0 [300, 570] [558.9999999999948, 163.99999999999835]
# KEY: DOWN
# True 0 [300, 580] [559.2999999999947, 164.19999999999834]
# KEY: UP
# True 0 [300, 570] [559.5999999999947, 164.39999999999833]
# KEY: UP
# True 0 [300, 560] [559.8999999999946, 164.59999999999832]
# KEY: RIGHT
# True 0 [300, 560] [560.1999999999946, 164.7999999999983]
# KEY: RIGHT
# True 0 [300, 560] [560.4999999999945, 164.9999999999983]
# KEY: RIGHT
# True 0 [300, 560] [560.7999999999945, 165.19999999999828]
# KEY: DOWN
# True 0 [300, 580] [561.0999999999945, 165.39999999999827]
# KEY: RIGHT
# True 0 [300, 580] [561.3999999999944, 165.59999999999826]
# KEY: DOWN
# True 0 [300, 580] [561.6999999999944, 165.79999999999825]
# KEY: LEFT
# True 0 [300, 580] [561.9999999999943, 165.99999999999824]
# KEY: LEFT
# True 0 [300, 580] [562.2999999999943, 166.19999999999823]
# KEY: RIGHT
# True 0 [300, 580] [562.5999999999942, 166.39999999999822]
# KEY: LEFT
# True 0 [300, 580] [562.8999999999942, 166.5999999999982]
# KEY: DOWN
# True 0 [300, 580] [563.1999999999941, 166.7999999999982]
# KEY: UP
# True 0 [300, 570] [563.4999999999941, 166.99999999999818]
# KEY: LEFT
# True 0 [300, 570] [563.799999999994, 167.19999999999817]
# KEY: RIGHT
# True 0 [300, 570] [564.099999999994, 167.39999999999816]
# KEY: UP
# True 0 [300, 560] [564.399999999994, 167.59999999999815]
# KEY: UP
# True 0 [300, 550] [564.6999999999939, 167.79999999999814]
# KEY: DOWN
# True 0 [300, 570] [564.9999999999939, 167.99999999999812]
# KEY: UP
# True 0 [300, 560] [565.2999999999938, 168.1999999999981]
# KEY: LEFT
# True 0 [300, 560] [565.5999999999938, 168.3999999999981]
# KEY: DOWN
# True 0 [300, 580] [565.8999999999937, 168.5999999999981]
# KEY: LEFT
# True 0 [300, 580] [566.1999999999937, 168.79999999999808]
# KEY: LEFT
# True 0 [300, 580] [566.4999999999936, 168.99999999999807]
# KEY: RIGHT
# True 0 [300, 580] [566.7999999999936, 169.19999999999806]
# KEY: RIGHT
# True 0 [300, 580] [567.0999999999935, 169.39999999999804]
# KEY: UP
# True 0 [300, 570] [567.3999999999935, 169.59999999999803]
# KEY: LEFT
# True 0 [300, 570] [567.6999999999935, 169.79999999999802]
# KEY: RIGHT
# True 0 [300, 570] [567.9999999999934, 169.999999999998]
# KEY: UP
# True 0 [300, 560] [568.2999999999934, 170.199999999998]
# KEY: UP
# True 0 [300, 550] [568.5999999999933, 170.399999999998]
# KEY: UP
# True 0 [300, 540] [568.8999999999933, 170.59999999999798]
# KEY: UP
# True 0 [300, 530] [569.1999999999932, 170.79999999999797]
# KEY: RIGHT
# True 0 [300, 530] [569.4999999999932, 170.99999999999795]
# KEY: DOWN
# True 0 [300, 550] [569.7999999999931, 171.19999999999794]
# KEY: DOWN
# True 0 [300, 570] [570.0999999999931, 171.39999999999793]
# KEY: UP
# True 0 [300, 560] [570.399999999993, 171.59999999999792]
# KEY: UP
# True 0 [300, 550] [570.699999999993, 171.7999999999979]
# KEY: UP
# True 0 [300, 540] [570.999999999993, 171.9999999999979]
# KEY: RIGHT
# True 0 [300, 540] [571.2999999999929, 172.19999999999789]
# KEY: RIGHT
# True 0 [300, 540] [571.5999999999929, 172.39999999999787]
# KEY: RIGHT
# True 0 [300, 540] [571.8999999999928, 172.59999999999786]
# KEY: LEFT
# True 0 [300, 540] [572.1999999999928, 172.79999999999785]
# KEY: RIGHT
# True 0 [300, 540] [572.4999999999927, 172.99999999999784]
# KEY: RIGHT
# True 0 [300, 540] [572.7999999999927, 173.19999999999783]
# KEY: UP
# True 0 [300, 530] [573.0999999999926, 173.39999999999782]
# KEY: UP
# True 0 [300, 520] [573.3999999999926, 173.5999999999978]
# KEY: RIGHT
# True 0 [300, 520] [573.6999999999925, 173.7999999999978]
# KEY: UP
# True 0 [300, 510] [573.9999999999925, 173.99999999999778]
# KEY: RIGHT
# True 0 [300, 510] [574.2999999999925, 174.19999999999777]
# KEY: RIGHT
# True 0 [300, 510] [574.5999999999924, 174.39999999999776]
# KEY: RIGHT
# True 0 [300, 510] [574.8999999999924, 174.59999999999775]
# KEY: LEFT
# True 0 [300, 510] [575.1999999999923, 174.79999999999774]
# KEY: RIGHT
# True 0 [300, 510] [575.4999999999923, 174.99999999999773]
# KEY: RIGHT
# True 0 [300, 510] [575.7999999999922, 175.19999999999771]
# KEY: UP
# True 0 [300, 500] [576.0999999999922, 175.3999999999977]
# KEY: RIGHT
# True 0 [300, 500] [576.3999999999921, 175.5999999999977]
# KEY: DOWN
# True 0 [300, 520] [576.6999999999921, 175.79999999999768]
# KEY: DOWN
# True 0 [300, 540] [576.999999999992, 175.99999999999767]
# KEY: RIGHT
# True 0 [300, 540] [577.299999999992, 176.19999999999766]
# KEY: DOWN
# True 0 [300, 560] [577.599999999992, 176.39999999999765]
# KEY: RIGHT
# True 0 [300, 560] [577.8999999999919, 176.59999999999764]
# KEY: UP
# True 0 [300, 550] [578.1999999999919, 176.79999999999762]
# KEY: UP
# True 0 [300, 540] [578.4999999999918, 176.9999999999976]
# KEY: DOWN
# True 0 [300, 560] [578.7999999999918, 177.1999999999976]
# KEY: LEFT
# True 0 [300, 560] [579.0999999999917, 177.3999999999976]
# KEY: DOWN
# True 0 [300, 580] [579.3999999999917, 177.59999999999758]
# KEY: RIGHT
# True 0 [300, 580] [579.6999999999916, 177.79999999999757]
# KEY: RIGHT
# True 0 [300, 580] [579.9999999999916, 177.99999999999756]
# KEY: UP
# True 0 [300, 570] [580.2999999999915, 178.19999999999754]
# KEY: DOWN
# True 0 [300, 580] [580.5999999999915, 178.39999999999753]
# KEY: LEFT
# True 0 [300, 580] [580.8999999999915, 178.59999999999752]
# KEY: RIGHT
# True 0 [300, 580] [581.1999999999914, 178.7999999999975]
# KEY: RIGHT
# True 0 [300, 580] [581.4999999999914, 178.9999999999975]
# KEY: UP
# True 0 [300, 570] [581.7999999999913, 179.1999999999975]
# KEY: UP
# True 0 [300, 560] [582.0999999999913, 179.39999999999748]
# KEY: UP
# True 0 [300, 550] [582.3999999999912, 179.59999999999746]
# KEY: DOWN
# True 0 [300, 570] [582.6999999999912, 179.79999999999745]
# KEY: UP
# True 0 [300, 560] [582.9999999999911, 179.99999999999744]
# KEY: DOWN
# True 0 [300, 580] [583.2999999999911, 180.19999999999743]
# KEY: LEFT
# True 0 [300, 580] [583.599999999991, 180.39999999999742]
# KEY: DOWN
# True 0 [300, 580] [583.899999999991, 180.5999999999974]
# KEY: UP
# True 0 [300, 570] [584.199999999991, 180.7999999999974]
# KEY: RIGHT
# True 0 [300, 570] [584.4999999999909, 180.99999999999739]
# KEY: RIGHT
# True 0 [300, 570] [584.7999999999909, 181.19999999999737]
# KEY: DOWN
# True 0 [300, 580] [585.0999999999908, 181.39999999999736]
# KEY: DOWN
# True 0 [300, 580] [584.8999999999908, 181.59999999999735]
# KEY: RIGHT
# True 0 [300, 580] [584.6999999999907, 181.79999999999734]
# KEY: LEFT
# True 0 [300, 580] [584.4999999999907, 181.99999999999733]
# KEY: UP
# True 0 [300, 570] [584.2999999999906, 182.19999999999732]
# KEY: LEFT
# True 0 [300, 570] [584.0999999999906, 182.3999999999973]
# KEY: DOWN
# True 0 [300, 580] [583.8999999999905, 182.5999999999973]
# KEY: UP
# True 0 [300, 570] [583.6999999999905, 182.79999999999728]
# KEY: DOWN
# True 0 [300, 580] [583.4999999999905, 182.99999999999727]
# KEY: RIGHT
# True 0 [300, 580] [583.2999999999904, 183.19999999999726]
# KEY: UP
# True 0 [300, 570] [583.0999999999904, 183.39999999999725]
# KEY: RIGHT
# True 0 [300, 570] [582.8999999999903, 183.59999999999724]
# KEY: RIGHT
# True 0 [300, 570] [582.6999999999903, 183.79999999999723]
# KEY: RIGHT
# True 0 [300, 570] [582.4999999999902, 183.99999999999721]
# KEY: RIGHT
# True 0 [300, 570] [582.2999999999902, 184.1999999999972]
# KEY: RIGHT
# True 0 [300, 570] [582.0999999999901, 184.3999999999972]
# KEY: LEFT
# True 0 [300, 570] [581.8999999999901, 184.59999999999718]
# KEY: RIGHT
# True 0 [300, 570] [581.69999999999, 184.79999999999717]
# KEY: UP
# True 0 [300, 560] [581.49999999999, 184.99999999999716]
# KEY: LEFT
# True 0 [300, 560] [581.29999999999, 185.19999999999715]
# KEY: DOWN
# True 0 [300, 580] [581.0999999999899, 185.39999999999714]
# KEY: DOWN
# True 0 [300, 580] [580.8999999999899, 185.59999999999712]
# KEY: RIGHT
# True 0 [300, 580] [580.6999999999898, 185.7999999999971]
# KEY: UP
# True 0 [300, 570] [580.4999999999898, 185.9999999999971]
# KEY: RIGHT
# True 0 [300, 570] [580.2999999999897, 186.1999999999971]
# KEY: LEFT
# True 0 [300, 570] [580.0999999999897, 186.39999999999708]
# KEY: DOWN
# True 0 [300, 580] [579.8999999999896, 186.59999999999707]
# KEY: RIGHT
# True 0 [300, 580] [579.6999999999896, 186.79999999999706]
# KEY: RIGHT
# True 0 [300, 580] [579.4999999999895, 186.99999999999704]
# KEY: RIGHT
# True 0 [300, 580] [579.2999999999895, 187.19999999999703]
# KEY: DOWN
# True 0 [300, 580] [579.0999999999894, 187.39999999999702]
# KEY: RIGHT
# True 0 [300, 580] [578.8999999999894, 187.599999999997]
# KEY: LEFT
# True 0 [300, 580] [578.6999999999894, 187.799999999997]
# KEY: DOWN
# True 0 [300, 580] [578.4999999999893, 187.999999999997]
# KEY: DOWN
# True 0 [300, 580] [578.2999999999893, 188.19999999999698]
# KEY: UP
# True 0 [300, 570] [578.0999999999892, 188.39999999999696]
# KEY: LEFT
# True 0 [300, 570] [577.8999999999892, 188.59999999999695]
# KEY: UP
# True 0 [300, 560] [577.6999999999891, 188.79999999999694]
# KEY: UP
# True 0 [300, 550] [577.4999999999891, 188.99999999999693]
# KEY: RIGHT
# True 0 [300, 550] [577.299999999989, 189.19999999999692]
# KEY: LEFT
# True 0 [300, 550] [577.099999999989, 189.3999999999969]
# KEY: UP
# True 0 [300, 540] [576.899999999989, 189.5999999999969]
# KEY: RIGHT
# True 0 [300, 540] [576.6999999999889, 189.79999999999688]
# KEY: RIGHT
# True 0 [300, 540] [576.4999999999889, 189.99999999999687]
# KEY: LEFT
# True 0 [300, 540] [576.2999999999888, 190.19999999999686]
# KEY: RIGHT
# True 0 [300, 540] [576.0999999999888, 190.39999999999685]
# KEY: LEFT
# True 0 [300, 540] [575.8999999999887, 190.59999999999684]
# KEY: LEFT
# True 0 [300, 540] [575.6999999999887, 190.79999999999683]
# KEY: LEFT
# True 0 [300, 540] [575.4999999999886, 190.99999999999682]
# KEY: RIGHT
# True 0 [300, 540] [575.2999999999886, 191.1999999999968]
# KEY: UP
# True 0 [300, 530] [575.0999999999885, 191.3999999999968]
# KEY: LEFT
# True 0 [300, 530] [574.8999999999885, 191.59999999999678]
# KEY: LEFT
# True 0 [300, 530] [574.6999999999884, 191.79999999999677]
# KEY: UP
# True 0 [300, 520] [574.4999999999884, 191.99999999999676]
# KEY: DOWN
# True 0 [300, 540] [574.2999999999884, 192.19999999999675]
# KEY: LEFT
# True 0 [300, 540] [574.0999999999883, 192.39999999999674]
# KEY: UP
# True 0 [300, 530] [573.8999999999883, 192.59999999999673]
# KEY: DOWN
# True 0 [300, 550] [573.6999999999882, 192.79999999999671]
# KEY: LEFT
# True 0 [300, 550] [573.4999999999882, 192.9999999999967]
# KEY: UP
# True 0 [300, 540] [573.2999999999881, 193.1999999999967]
# KEY: UP
# True 0 [300, 530] [573.0999999999881, 193.39999999999668]
# KEY: LEFT
# True 0 [300, 530] [572.899999999988, 193.59999999999667]
# KEY: DOWN
# True 0 [300, 550] [572.699999999988, 193.79999999999666]
# KEY: RIGHT
# True 0 [300, 550] [572.499999999988, 193.99999999999665]
# KEY: DOWN
# True 0 [300, 570] [572.2999999999879, 194.19999999999663]
# KEY: UP
# True 0 [300, 560] [572.0999999999879, 194.39999999999662]
# KEY: LEFT
# True 0 [300, 560] [571.8999999999878, 194.5999999999966]
# KEY: LEFT
# True 0 [300, 560] [571.6999999999878, 194.7999999999966]
# KEY: DOWN
# True 0 [300, 580] [571.4999999999877, 194.9999999999966]
# KEY: DOWN
# True 0 [300, 580] [571.2999999999877, 195.19999999999658]
# KEY: RIGHT
# True 0 [300, 580] [571.0999999999876, 195.39999999999657]
# KEY: LEFT
# True 0 [300, 580] [570.8999999999876, 195.59999999999656]
# KEY: UP
# True 0 [300, 570] [570.6999999999875, 195.79999999999654]
# KEY: UP
# True 0 [300, 560] [570.4999999999875, 195.99999999999653]
# KEY: DOWN
# True 0 [300, 580] [570.2999999999874, 196.19999999999652]
# KEY: UP
# True 0 [300, 570] [570.0999999999874, 196.3999999999965]
# KEY: LEFT
# True 0 [300, 570] [569.8999999999874, 196.5999999999965]
# KEY: RIGHT
# True 0 [300, 570] [569.6999999999873, 196.7999999999965]
# KEY: UP
# True 0 [300, 560] [569.4999999999873, 196.99999999999648]
# KEY: DOWN
# True 0 [300, 580] [569.2999999999872, 197.19999999999646]
# KEY: RIGHT
# True 0 [300, 580] [569.0999999999872, 197.39999999999645]
# KEY: DOWN
# True 0 [300, 580] [568.8999999999871, 197.59999999999644]
# KEY: LEFT
# True 0 [300, 580] [568.6999999999871, 197.79999999999643]
# KEY: DOWN
# True 0 [300, 580] [568.499999999987, 197.99999999999642]
# KEY: LEFT
# True 0 [300, 580] [568.299999999987, 198.1999999999964]
# KEY: DOWN
# True 0 [300, 580] [568.099999999987, 198.3999999999964]
# KEY: RIGHT
# True 0 [300, 580] [567.8999999999869, 198.59999999999638]
# KEY: UP
# True 0 [300, 570] [567.6999999999869, 198.79999999999637]
# KEY: DOWN
# True 0 [300, 580] [567.4999999999868, 198.99999999999636]
# KEY: DOWN
# True 0 [300, 580] [567.2999999999868, 199.19999999999635]
# KEY: UP
# True 0 [300, 570] [567.0999999999867, 199.39999999999634]
# KEY: LEFT
# True 0 [300, 570] [566.8999999999867, 199.59999999999633]
# KEY: DOWN
# True 0 [300, 580] [566.6999999999866, 199.79999999999632]
# KEY: RIGHT
# True 0 [300, 580] [566.4999999999866, 199.9999999999963]
# KEY: RIGHT
# True 0 [300, 580] [566.2999999999865, 200.1999999999963]
# KEY: RIGHT
# True 0 [300, 580] [566.0999999999865, 200.39999999999628]
# KEY: DOWN
# True 0 [300, 580] [565.8999999999864, 200.59999999999627]
# KEY: UP
# True 0 [300, 570] [565.6999999999864, 200.79999999999626]
# KEY: RIGHT
# True 0 [300, 570] [565.4999999999864, 200.99999999999625]
# KEY: DOWN
# True 0 [300, 580] [565.2999999999863, 201.19999999999624]
# KEY: RIGHT
# True 0 [300, 580] [565.0999999999863, 201.39999999999623]
# KEY: DOWN
# True 0 [300, 580] [564.8999999999862, 201.59999999999621]
# KEY: DOWN
# True 0 [300, 580] [564.6999999999862, 201.7999999999962]
# KEY: UP
# True 0 [300, 570] [564.4999999999861, 201.9999999999962]
# KEY: LEFT
# True 0 [300, 570] [564.2999999999861, 202.19999999999618]
# KEY: RIGHT
# True 0 [300, 570] [564.099999999986, 202.39999999999617]
# KEY: UP
# True 0 [300, 560] [563.899999999986, 202.59999999999616]
# KEY: RIGHT
# True 0 [300, 560] [563.699999999986, 202.79999999999615]
# KEY: LEFT
# True 0 [300, 560] [563.4999999999859, 202.99999999999613]
# KEY: RIGHT
# True 0 [300, 560] [563.2999999999859, 203.19999999999612]
# KEY: DOWN
# True 0 [300, 580] [563.0999999999858, 203.3999999999961]
# KEY: DOWN
# True 0 [300, 580] [562.8999999999858, 203.5999999999961]
# KEY: DOWN
# True 0 [300, 580] [562.6999999999857, 203.7999999999961]
# KEY: DOWN
# True 0 [300, 580] [562.4999999999857, 203.99999999999608]
# KEY: DOWN
# True 0 [300, 580] [562.2999999999856, 204.19999999999607]
# KEY: RIGHT
# True 0 [300, 580] [562.0999999999856, 204.39999999999606]
# KEY: DOWN
# True 0 [300, 580] [561.8999999999855, 204.59999999999604]
# KEY: UP
# True 0 [300, 570] [561.6999999999855, 204.79999999999603]
# KEY: UP
# True 0 [300, 560] [561.4999999999854, 204.99999999999602]
# KEY: DOWN
# True 0 [300, 580] [561.2999999999854, 205.199999999996]
# KEY: RIGHT
# True 0 [300, 580] [561.0999999999854, 205.399999999996]
# KEY: RIGHT
# True 0 [300, 580] [560.8999999999853, 205.599999999996]
# KEY: RIGHT
# True 0 [300, 580] [560.6999999999853, 205.79999999999598]
# KEY: UP
# True 0 [300, 570] [560.4999999999852, 205.99999999999596]
# KEY: DOWN
# True 0 [300, 580] [560.2999999999852, 206.19999999999595]
# KEY: LEFT
# True 0 [300, 580] [560.0999999999851, 206.39999999999594]
# KEY: DOWN
# True 0 [300, 580] [559.8999999999851, 206.59999999999593]
# KEY: LEFT
# True 0 [300, 580] [559.699999999985, 206.79999999999592]
# KEY: UP
# True 0 [300, 570] [559.499999999985, 206.9999999999959]
# KEY: DOWN
# True 0 [300, 580] [559.299999999985, 207.1999999999959]
# KEY: RIGHT
# True 0 [300, 580] [559.0999999999849, 207.39999999999588]
# KEY: LEFT
# True 0 [300, 580] [558.8999999999849, 207.59999999999587]
# KEY: RIGHT
# True 0 [300, 580] [558.6999999999848, 207.79999999999586]
# KEY: DOWN
# True 0 [300, 580] [558.4999999999848, 207.99999999999585]
# KEY: LEFT
# True 0 [300, 580] [558.2999999999847, 208.19999999999584]
# KEY: RIGHT
# True 0 [300, 580] [558.0999999999847, 208.39999999999583]
# KEY: RIGHT
# True 0 [300, 580] [557.8999999999846, 208.59999999999582]
# KEY: DOWN
# True 0 [300, 580] [557.6999999999846, 208.7999999999958]
# KEY: LEFT
# True 0 [300, 580] [557.4999999999845, 208.9999999999958]
# KEY: DOWN
# True 0 [300, 580] [557.2999999999845, 209.19999999999578]
# KEY: LEFT
# True 0 [300, 580] [557.0999999999844, 209.39999999999577]
# KEY: UP
# True 0 [300, 570] [556.8999999999844, 209.59999999999576]
# KEY: LEFT
# True 0 [300, 570] [556.6999999999844, 209.79999999999575]
# KEY: DOWN
# True 0 [300, 580] [556.4999999999843, 209.99999999999574]
# KEY: UP
# True 0 [300, 570] [556.2999999999843, 210.19999999999573]
# KEY: UP
# True 0 [300, 560] [556.0999999999842, 210.3999999999957]
# KEY: DOWN
# True 0 [300, 580] [555.8999999999842, 210.5999999999957]
# KEY: DOWN
# True 0 [300, 580] [555.6999999999841, 210.7999999999957]
# KEY: RIGHT
# True 0 [300, 580] [555.4999999999841, 210.99999999999568]
# KEY: RIGHT
# True 0 [300, 580] [555.299999999984, 211.19999999999567]
# KEY: UP
# True 0 [300, 570] [555.099999999984, 211.39999999999566]
# KEY: UP
# True 0 [300, 560] [554.899999999984, 211.59999999999565]
# KEY: UP
# True 0 [300, 550] [554.6999999999839, 211.79999999999563]
# KEY: LEFT
# True 0 [300, 550] [554.4999999999839, 211.99999999999562]
# KEY: UP
# True 0 [300, 540] [554.2999999999838, 212.1999999999956]
# KEY: LEFT
# True 0 [300, 540] [554.0999999999838, 212.3999999999956]
# KEY: RIGHT
# True 0 [300, 540] [553.8999999999837, 212.5999999999956]
# KEY: UP
# True 0 [300, 530] [553.6999999999837, 212.79999999999558]
# KEY: LEFT
# True 0 [300, 530] [553.4999999999836, 212.99999999999557]
# KEY: DOWN
# True 0 [300, 550] [553.2999999999836, 213.19999999999555]
# KEY: DOWN
# True 0 [300, 570] [553.0999999999835, 213.39999999999554]
# KEY: DOWN
# True 0 [300, 580] [552.8999999999835, 213.59999999999553]
# KEY: RIGHT
# True 0 [300, 580] [552.6999999999834, 213.79999999999552]
# KEY: UP
# True 0 [300, 570] [552.4999999999834, 213.9999999999955]
# KEY: RIGHT
# True 0 [300, 570] [552.2999999999834, 214.1999999999955]
# KEY: UP
# True 0 [300, 560] [552.0999999999833, 214.3999999999955]
# KEY: UP
# True 0 [300, 550] [551.8999999999833, 214.59999999999548]
# KEY: RIGHT
# True 0 [300, 550] [551.6999999999832, 214.79999999999546]
# KEY: UP
# True 0 [300, 540] [551.4999999999832, 214.99999999999545]
# KEY: LEFT
# True 0 [300, 540] [551.2999999999831, 215.19999999999544]
# KEY: LEFT
# True 0 [300, 540] [551.0999999999831, 215.39999999999543]
# KEY: RIGHT
# True 0 [300, 540] [550.899999999983, 215.59999999999542]
# KEY: LEFT
# True 0 [300, 540] [550.699999999983, 215.7999999999954]
# KEY: LEFT
# True 0 [300, 540] [550.499999999983, 215.9999999999954]
# KEY: UP
# True 0 [300, 530] [550.2999999999829, 216.19999999999538]
# KEY: UP
# True 0 [300, 520] [550.0999999999829, 216.39999999999537]
# KEY: RIGHT
# True 0 [300, 520] [549.8999999999828, 216.59999999999536]
# KEY: UP
# True 0 [300, 510] [549.6999999999828, 216.79999999999535]
# KEY: RIGHT
# True 0 [300, 510] [549.4999999999827, 216.99999999999534]
# KEY: RIGHT
# True 0 [300, 510] [549.2999999999827, 217.19999999999533]
# KEY: RIGHT
# True 0 [300, 510] [549.0999999999826, 217.39999999999532]
# KEY: UP
# True 0 [300, 500] [548.8999999999826, 217.5999999999953]
# KEY: LEFT
# True 0 [300, 500] [548.6999999999825, 217.7999999999953]
# KEY: LEFT
# True 0 [300, 500] [548.4999999999825, 217.99999999999528]
# KEY: LEFT
# True 0 [300, 500] [548.2999999999824, 218.19999999999527]
# KEY: RIGHT
# True 0 [300, 500] [548.0999999999824, 218.39999999999526]
# KEY: DOWN
# True 0 [300, 520] [547.8999999999824, 218.59999999999525]
# KEY: LEFT
# True 0 [300, 520] [547.6999999999823, 218.79999999999524]
# KEY: LEFT
# True 0 [300, 520] [547.4999999999823, 218.99999999999523]
# KEY: LEFT
# True 0 [300, 520] [547.2999999999822, 219.1999999999952]
# KEY: UP
# True 0 [300, 510] [547.0999999999822, 219.3999999999952]
# KEY: RIGHT
# True 0 [300, 510] [546.8999999999821, 219.5999999999952]
# KEY: DOWN
# True 0 [300, 530] [546.6999999999821, 219.79999999999518]
# KEY: RIGHT
# True 0 [300, 530] [546.499999999982, 219.99999999999517]
# KEY: RIGHT
# True 0 [300, 530] [546.299999999982, 220.19999999999516]
# KEY: RIGHT
# True 0 [300, 530] [546.099999999982, 220.39999999999515]
# KEY: LEFT
# True 0 [300, 530] [545.8999999999819, 220.59999999999513]
# KEY: UP
# True 0 [300, 520] [545.6999999999819, 220.79999999999512]
# KEY: RIGHT
# True 0 [300, 520] [545.4999999999818, 220.9999999999951]
# KEY: RIGHT
# True 0 [300, 520] [545.2999999999818, 221.1999999999951]
# KEY: DOWN
# True 0 [300, 540] [545.0999999999817, 221.3999999999951]
# KEY: UP
# True 0 [300, 530] [544.8999999999817, 221.59999999999508]
# KEY: LEFT
# True 0 [300, 530] [544.6999999999816, 221.79999999999507]
# KEY: RIGHT
# True 0 [300, 530] [544.4999999999816, 221.99999999999505]
# KEY: RIGHT
# True 0 [300, 530] [544.2999999999815, 222.19999999999504]
# KEY: DOWN
# True 0 [300, 550] [544.0999999999815, 222.39999999999503]
# KEY: RIGHT
# True 0 [300, 550] [543.8999999999814, 222.59999999999502]
# KEY: DOWN
# True 0 [300, 570] [543.6999999999814, 222.799999999995]
# KEY: RIGHT
# True 0 [300, 570] [543.4999999999814, 222.999999999995]
# KEY: LEFT
# True 0 [300, 570] [543.2999999999813, 223.199999999995]
# KEY: LEFT
# True 0 [300, 570] [543.0999999999813, 223.39999999999498]
# KEY: RIGHT
# True 0 [300, 570] [542.8999999999812, 223.59999999999496]
# KEY: DOWN
# True 0 [300, 580] [542.6999999999812, 223.79999999999495]
# KEY: UP
# True 0 [300, 570] [542.4999999999811, 223.99999999999494]
# KEY: UP
# True 0 [300, 560] [542.2999999999811, 224.19999999999493]
# KEY: LEFT
# True 0 [300, 560] [542.099999999981, 224.39999999999492]
# KEY: LEFT
# True 0 [300, 560] [541.899999999981, 224.5999999999949]
# KEY: DOWN
# True 0 [300, 580] [541.699999999981, 224.7999999999949]
# KEY: RIGHT
# True 0 [300, 580] [541.4999999999809, 224.99999999999488]
# KEY: DOWN
# True 0 [300, 580] [541.2999999999809, 225.19999999999487]
# KEY: UP
# True 0 [300, 570] [541.0999999999808, 225.39999999999486]
# KEY: UP
# True 0 [300, 560] [540.8999999999808, 225.59999999999485]
# KEY: LEFT
# True 0 [300, 560] [540.6999999999807, 225.79999999999484]
# KEY: RIGHT
# True 0 [300, 560] [540.4999999999807, 225.99999999999483]
# KEY: DOWN
# True 0 [300, 580] [540.2999999999806, 226.19999999999482]
# KEY: DOWN
# True 0 [300, 580] [540.0999999999806, 226.3999999999948]
# KEY: RIGHT
# True 0 [300, 580] [539.8999999999805, 226.5999999999948]
# KEY: UP
# True 0 [300, 570] [539.6999999999805, 226.79999999999478]
# KEY: LEFT
# True 0 [300, 570] [539.4999999999804, 226.99999999999477]
# KEY: RIGHT
# True 0 [300, 570] [539.2999999999804, 227.19999999999476]
# KEY: UP
# True 0 [300, 560] [539.0999999999804, 227.39999999999475]
# KEY: LEFT
# True 0 [300, 560] [538.8999999999803, 227.59999999999474]
# KEY: UP
# True 0 [300, 550] [538.6999999999803, 227.79999999999472]
# KEY: LEFT
# True 0 [300, 550] [538.4999999999802, 227.9999999999947]
# KEY: LEFT
# True 0 [300, 550] [538.2999999999802, 228.1999999999947]
# KEY: RIGHT
# True 0 [300, 550] [538.0999999999801, 228.3999999999947]
# KEY: UP
# True 0 [300, 540] [537.8999999999801, 228.59999999999468]
# KEY: DOWN
# True 0 [300, 560] [537.69999999998, 228.79999999999467]
# KEY: RIGHT
# True 0 [300, 560] [537.49999999998, 228.99999999999466]
# KEY: RIGHT
# True 0 [300, 560] [537.29999999998, 229.19999999999465]
# KEY: RIGHT
# True 0 [300, 560] [537.0999999999799, 229.39999999999463]
# KEY: RIGHT
# True 0 [300, 560] [536.8999999999799, 229.59999999999462]
# KEY: LEFT
# True 0 [300, 560] [536.6999999999798, 229.7999999999946]
# KEY: DOWN
# True 0 [300, 580] [536.4999999999798, 229.9999999999946]
# KEY: LEFT
# True 0 [300, 580] [536.2999999999797, 230.1999999999946]
# KEY: LEFT
# True 0 [300, 580] [536.0999999999797, 230.39999999999458]
# KEY: LEFT
# True 0 [300, 580] [535.8999999999796, 230.59999999999457]
# KEY: DOWN
# True 0 [300, 580] [535.6999999999796, 230.79999999999455]
# KEY: DOWN
# True 0 [300, 580] [535.4999999999795, 230.99999999999454]
# KEY: DOWN
# True 0 [300, 580] [535.2999999999795, 231.19999999999453]
# KEY: UP
# True 0 [300, 570] [535.0999999999794, 231.39999999999452]
# KEY: UP
# True 0 [300, 560] [534.8999999999794, 231.5999999999945]
# KEY: LEFT
# True 0 [300, 560] [534.6999999999794, 231.7999999999945]
# KEY: RIGHT
# True 0 [300, 560] [534.4999999999793, 231.9999999999945]
# KEY: LEFT
# True 0 [300, 560] [534.2999999999793, 232.19999999999447]
# KEY: UP
# True 0 [300, 550] [534.0999999999792, 232.39999999999446]
# KEY: DOWN
# True 0 [300, 570] [533.8999999999792, 232.59999999999445]
# KEY: LEFT
# True 0 [300, 570] [533.6999999999791, 232.79999999999444]
# KEY: DOWN
# True 0 [300, 580] [533.4999999999791, 232.99999999999443]
# KEY: UP
# True 0 [300, 570] [533.299999999979, 233.19999999999442]
# KEY: LEFT
# True 0 [300, 570] [533.099999999979, 233.3999999999944]
# KEY: LEFT
# True 0 [300, 570] [532.899999999979, 233.5999999999944]
# KEY: DOWN
# True 0 [300, 580] [532.6999999999789, 233.79999999999438]
# KEY: DOWN
# True 0 [300, 580] [532.4999999999789, 233.99999999999437]
# KEY: DOWN
# True 0 [300, 580] [532.2999999999788, 234.19999999999436]
# KEY: DOWN
# True 0 [300, 580] [532.0999999999788, 234.39999999999435]
# KEY: LEFT
# True 0 [300, 580] [531.8999999999787, 234.59999999999434]
# KEY: LEFT
# True 0 [300, 580] [531.6999999999787, 234.79999999999433]
# KEY: UP
# True 0 [300, 570] [531.4999999999786, 234.99999999999432]
# KEY: DOWN
# True 0 [300, 580] [531.2999999999786, 235.1999999999943]
# KEY: LEFT
# True 0 [300, 580] [531.0999999999785, 235.3999999999943]
# KEY: DOWN
# True 0 [300, 580] [530.8999999999785, 235.59999999999428]
# KEY: RIGHT
# True 0 [300, 580] [530.6999999999784, 235.79999999999427]
# KEY: UP
# True 0 [300, 570] [530.4999999999784, 235.99999999999426]
# KEY: LEFT
# True 0 [300, 570] [530.2999999999784, 236.19999999999425]
# KEY: DOWN
# True 0 [300, 580] [530.0999999999783, 236.39999999999424]
# KEY: UP
# True 0 [300, 570] [529.8999999999783, 236.59999999999422]
# KEY: RIGHT
# True 0 [300, 570] [529.6999999999782, 236.7999999999942]
# KEY: RIGHT
# True 0 [300, 570] [529.4999999999782, 236.9999999999942]
# KEY: UP
# True 0 [300, 560] [529.2999999999781, 237.1999999999942]
# KEY: RIGHT
# True 0 [300, 560] [529.0999999999781, 237.39999999999418]
# KEY: DOWN
# True 0 [300, 580] [528.899999999978, 237.59999999999417]
# KEY: RIGHT
# True 0 [300, 580] [528.699999999978, 237.79999999999416]
# KEY: DOWN
# True 0 [300, 580] [528.499999999978, 237.99999999999415]
# KEY: DOWN
# True 0 [300, 580] [528.2999999999779, 238.19999999999413]
# KEY: UP
# True 0 [300, 570] [528.0999999999779, 238.39999999999412]
# KEY: DOWN
# True 0 [300, 580] [527.8999999999778, 238.5999999999941]
# KEY: RIGHT
# True 0 [300, 580] [527.6999999999778, 238.7999999999941]
# KEY: DOWN
# True 0 [300, 580] [527.4999999999777, 238.9999999999941]
# KEY: UP
# True 0 [300, 570] [527.2999999999777, 239.19999999999408]
# KEY: LEFT
# True 0 [300, 570] [527.0999999999776, 239.39999999999407]
# KEY: UP
# True 0 [300, 560] [526.8999999999776, 239.59999999999405]
# KEY: LEFT
# True 0 [300, 560] [526.6999999999775, 239.79999999999404]
# KEY: LEFT
# True 0 [300, 560] [526.4999999999775, 239.99999999999403]
# KEY: DOWN
# True 0 [300, 580] [526.2999999999774, 240.19999999999402]
# KEY: UP
# True 0 [300, 570] [526.0999999999774, 240.399999999994]
# KEY: UP
# True 0 [300, 560] [525.8999999999774, 240.599999999994]
# KEY: UP
# True 0 [300, 550] [525.6999999999773, 240.799999999994]
# KEY: LEFT
# True 0 [300, 550] [525.4999999999773, 240.99999999999397]
# KEY: UP
# True 0 [300, 540] [525.2999999999772, 241.19999999999396]
# KEY: UP
# True 0 [300, 530] [525.0999999999772, 241.39999999999395]
# KEY: UP
# True 0 [300, 520] [524.8999999999771, 241.59999999999394]
# KEY: UP
# True 0 [300, 510] [524.6999999999771, 241.79999999999393]
# KEY: LEFT
# True 0 [300, 510] [524.499999999977, 241.99999999999392]
# KEY: DOWN
# True 0 [300, 530] [524.299999999977, 242.1999999999939]
# KEY: LEFT
# True 0 [300, 530] [524.099999999977, 242.3999999999939]
# KEY: LEFT
# ...
# KEY: UP
# True 1 [300, 570] [156.80000000002008, 453.1999999999819]
# KEY: RIGHT
# True 1 [300, 570] [156.6000000000201, 453.3999999999819]
# KEY: LEFT
# True 1 [300, 570] [156.4000000000201, 453.5999999999819]
# KEY: RIGHT
# True 1 [300, 570] [156.2000000000201, 453.7999999999819]
# KEY: LEFT
# True 1 [300, 570] [156.00000000002012, 453.99999999998187]
# KEY: UP
# True 1 [300, 560] [155.80000000002013, 454.19999999998186]
# KEY: LEFT
# True 1 [300, 560] [155.60000000002015, 454.39999999998184]
# KEY: UP
# True 1 [300, 550] [155.40000000002016, 454.59999999998183]
# KEY: UP
# True 1 [300, 540] [155.20000000002017, 454.7999999999818]
# KEY: DOWN
# True 1 [300, 560] [155.00000000002018, 454.9999999999818]
# KEY: RIGHT
# True 1 [300, 560] [154.8000000000202, 455.1999999999818]
# KEY: DOWN
# True 1 [300, 580] [154.6000000000202, 455.3999999999818]
# KEY: UP
# True 1 [300, 570] [154.4000000000202, 455.5999999999818]
# KEY: DOWN
# True 1 [300, 580] [154.20000000002022, 455.79999999998176]
# KEY: RIGHT
# True 1 [300, 580] [154.00000000002024, 455.99999999998175]
# KEY: LEFT
# True 1 [300, 580] [153.80000000002025, 456.19999999998174]
# KEY: UP
# True 1 [300, 570] [153.60000000002026, 456.39999999998173]
# KEY: UP
# True 1 [300, 560] [153.40000000002027, 456.5999999999817]
# KEY: DOWN
# True 1 [300, 580] [153.20000000002028, 456.7999999999817]
# KEY: LEFT
# True 1 [300, 580] [153.0000000000203, 456.9999999999817]
# KEY: DOWN
# True 1 [300, 580] [152.8000000000203, 457.1999999999817]
# KEY: DOWN
# True 1 [300, 580] [152.60000000002032, 457.3999999999817]
# KEY: LEFT
# True 1 [300, 580] [152.40000000002033, 457.59999999998166]
# KEY: LEFT
# True 1 [300, 580] [152.20000000002034, 457.79999999998165]
# KEY: LEFT
# True 1 [300, 580] [152.00000000002035, 457.99999999998164]
# KEY: DOWN
# True 1 [300, 580] [151.80000000002036, 458.1999999999816]
# KEY: DOWN
# True 1 [300, 580] [151.60000000002037, 458.3999999999816]
# KEY: DOWN
# True 1 [300, 580] [151.40000000002038, 458.5999999999816]
# KEY: UP
# True 1 [300, 570] [151.2000000000204, 458.7999999999816]
# KEY: LEFT
# True 1 [300, 570] [151.0000000000204, 458.9999999999816]
# KEY: RIGHT
# True 1 [300, 570] [150.80000000002042, 459.19999999998157]
# KEY: DOWN
# True 1 [300, 580] [150.60000000002043, 459.39999999998156]
# KEY: UP
# True 1 [300, 570] [150.40000000002044, 459.59999999998155]
# KEY: RIGHT
# True 1 [300, 570] [150.20000000002045, 459.79999999998154]
# KEY: LEFT
# True 1 [300, 570] [150.00000000002046, 459.9999999999815]
# KEY: LEFT
# True 1 [300, 570] [149.80000000002047, 460.1999999999815]
# KEY: DOWN
# True 1 [300, 580] [149.6000000000205, 460.3999999999815]
# KEY: UP
# True 1 [300, 570] [149.4000000000205, 460.5999999999815]
# KEY: RIGHT
# True 1 [300, 570] [149.2000000000205, 460.7999999999815]
# KEY: LEFT
# True 1 [300, 570] [149.00000000002052, 460.99999999998147]
# KEY: RIGHT
# True 1 [300, 570] [148.80000000002053, 461.19999999998146]
# KEY: LEFT
# True 1 [300, 570] [148.60000000002054, 461.39999999998145]
# KEY: DOWN
# True 1 [300, 580] [148.40000000002055, 461.59999999998143]
# KEY: LEFT
# True 1 [300, 580] [148.20000000002057, 461.7999999999814]
# KEY: UP
# True 1 [300, 570] [148.00000000002058, 461.9999999999814]
# KEY: UP
# True 1 [300, 560] [147.8000000000206, 462.1999999999814]
# KEY: LEFT
# True 1 [300, 560] [147.6000000000206, 462.3999999999814]
# KEY: RIGHT
# True 1 [300, 560] [147.4000000000206, 462.5999999999814]
# KEY: RIGHT
# True 1 [300, 560] [147.20000000002062, 462.79999999998137]
# KEY: LEFT
# True 1 [300, 560] [147.00000000002063, 462.99999999998136]
# KEY: DOWN
# True 1 [300, 580] [146.80000000002065, 463.19999999998134]
# KEY: RIGHT
# True 1 [300, 580] [146.60000000002066, 463.39999999998133]
# KEY: DOWN
# True 1 [300, 580] [146.40000000002067, 463.5999999999813]
# KEY: UP
# True 1 [300, 570] [146.20000000002068, 463.7999999999813]
# KEY: DOWN
# True 1 [300, 580] [146.0000000000207, 463.9999999999813]
# KEY: UP
# True 1 [300, 570] [145.8000000000207, 464.1999999999813]
# KEY: UP
# True 1 [300, 560] [145.6000000000207, 464.3999999999813]
# KEY: RIGHT
# True 1 [300, 560] [145.40000000002073, 464.59999999998126]
# KEY: UP
# True 1 [300, 550] [145.20000000002074, 464.79999999998125]
# KEY: RIGHT
# True 1 [300, 550] [145.00000000002075, 464.99999999998124]
# KEY: LEFT
# True 1 [300, 550] [144.80000000002076, 465.19999999998123]
# KEY: UP
# True 1 [300, 540] [144.60000000002077, 465.3999999999812]
# KEY: RIGHT
# True 1 [300, 540] [144.40000000002078, 465.5999999999812]
# KEY: LEFT
# True 1 [300, 540] [144.2000000000208, 465.7999999999812]
# KEY: RIGHT
# True 1 [300, 540] [144.0000000000208, 465.9999999999812]
# KEY: DOWN
# True 1 [300, 560] [143.80000000002082, 466.1999999999812]
# KEY: RIGHT
# True 1 [300, 560] [143.60000000002083, 466.39999999998116]
# KEY: LEFT
# True 1 [300, 560] [143.40000000002084, 466.59999999998115]
# KEY: RIGHT
# True 1 [300, 560] [143.20000000002085, 466.79999999998114]
# KEY: RIGHT
# True 1 [300, 560] [143.00000000002086, 466.9999999999811]
# KEY: LEFT
# True 1 [300, 560] [142.80000000002087, 467.1999999999811]
# KEY: UP
# True 1 [300, 550] [142.60000000002088, 467.3999999999811]
# KEY: UP
# True 1 [300, 540] [142.4000000000209, 467.5999999999811]
# KEY: DOWN
# True 1 [300, 560] [142.2000000000209, 467.7999999999811]
# KEY: UP
# True 1 [300, 550] [142.00000000002092, 467.99999999998107]
# KEY: LEFT
# True 1 [300, 550] [141.80000000002093, 468.19999999998106]
# KEY: LEFT
# True 1 [300, 550] [141.60000000002094, 468.39999999998105]
# KEY: UP
# True 1 [300, 540] [141.40000000002095, 468.59999999998104]
# KEY: UP
# True 1 [300, 530] [141.20000000002096, 468.799999999981]
# KEY: RIGHT
# True 1 [300, 530] [141.00000000002098, 468.999999999981]
# KEY: RIGHT
# True 1 [300, 530] [140.800000000021, 469.199999999981]
# KEY: DOWN
# True 1 [300, 550] [140.600000000021, 469.399999999981]
# KEY: DOWN
# True 1 [300, 570] [140.400000000021, 469.599999999981]
# KEY: UP
# True 1 [300, 560] [140.20000000002102, 469.79999999998097]
# KEY: RIGHT
# True 1 [300, 560] [140.00000000002103, 469.99999999998096]
# KEY: RIGHT
# True 1 [300, 560] [139.80000000002104, 470.19999999998095]
# KEY: RIGHT
# True 1 [300, 560] [139.60000000002105, 470.39999999998093]
# KEY: DOWN
# True 1 [300, 580] [139.40000000002107, 470.5999999999809]
# KEY: UP
# True 1 [300, 570] [139.20000000002108, 470.7999999999809]
# KEY: RIGHT
# True 1 [300, 570] [139.0000000000211, 470.9999999999809]
# KEY: RIGHT
# True 1 [300, 570] [138.8000000000211, 471.1999999999809]
# KEY: UP
# True 1 [300, 560] [138.6000000000211, 471.3999999999809]
# KEY: RIGHT
# True 1 [300, 560] [138.40000000002112, 471.59999999998087]
# KEY: UP
# True 1 [300, 550] [138.20000000002113, 471.79999999998086]
# KEY: LEFT
# True 1 [300, 550] [138.00000000002115, 471.99999999998084]
# KEY: UP
# True 1 [300, 540] [137.80000000002116, 472.19999999998083]
# KEY: RIGHT
# True 1 [300, 540] [137.60000000002117, 472.3999999999808]
# KEY: DOWN
# True 1 [300, 560] [137.40000000002118, 472.5999999999808]
# KEY: RIGHT
# True 1 [300, 560] [137.2000000000212, 472.7999999999808]
# KEY: RIGHT
# True 1 [300, 560] [137.0000000000212, 472.9999999999808]
# KEY: RIGHT
# True 1 [300, 560] [136.8000000000212, 473.1999999999808]
# KEY: UP
# True 1 [300, 550] [136.60000000002123, 473.39999999998076]
# KEY: RIGHT
# True 1 [300, 550] [136.40000000002124, 473.59999999998075]
# KEY: RIGHT
# True 1 [300, 550] [136.20000000002125, 473.79999999998074]
# KEY: UP
# True 1 [300, 540] [136.00000000002126, 473.99999999998073]
# KEY: RIGHT
# True 1 [300, 540] [135.80000000002127, 474.1999999999807]
# KEY: UP
# True 1 [300, 530] [135.60000000002128, 474.3999999999807]
# KEY: DOWN
# True 1 [300, 550] [135.4000000000213, 474.5999999999807]
# KEY: DOWN
# True 1 [300, 570] [135.2000000000213, 474.7999999999807]
# KEY: LEFT
# True 1 [300, 570] [135.00000000002132, 474.9999999999807]
# KEY: LEFT
# True 1 [300, 570] [134.80000000002133, 475.19999999998066]
# KEY: LEFT
# True 1 [300, 570] [134.60000000002134, 475.39999999998065]
# KEY: DOWN
# True 1 [300, 580] [134.40000000002135, 475.59999999998064]
# KEY: DOWN
# True 1 [300, 580] [134.20000000002136, 475.7999999999806]
# KEY: RIGHT
# True 1 [300, 580] [134.00000000002137, 475.9999999999806]
# KEY: RIGHT
# True 1 [300, 580] [133.80000000002138, 476.1999999999806]
# KEY: DOWN
# True 1 [300, 580] [133.6000000000214, 476.3999999999806]
# KEY: DOWN
# True 1 [300, 580] [133.4000000000214, 476.5999999999806]
# KEY: DOWN
# True 1 [300, 580] [133.20000000002142, 476.79999999998057]
# KEY: UP
# True 1 [300, 570] [133.00000000002143, 476.99999999998056]
# KEY: UP
# True 1 [300, 560] [132.80000000002144, 477.19999999998055]
# KEY: LEFT
# True 1 [300, 560] [132.60000000002145, 477.39999999998054]
# KEY: LEFT
# True 1 [300, 560] [132.40000000002146, 477.5999999999805]
# KEY: LEFT
# True 1 [300, 560] [132.20000000002148, 477.7999999999805]
# KEY: UP
# True 1 [300, 550] [132.0000000000215, 477.9999999999805]
# KEY: DOWN
# True 1 [300, 570] [131.8000000000215, 478.1999999999805]
# KEY: UP
# True 1 [300, 560] [131.6000000000215, 478.3999999999805]
# KEY: LEFT
# True 1 [300, 560] [131.40000000002152, 478.59999999998047]
# KEY: LEFT
# True 1 [300, 560] [131.20000000002153, 478.79999999998046]
# KEY: LEFT
# True 1 [300, 560] [131.00000000002154, 478.99999999998045]
# KEY: DOWN
# True 1 [300, 580] [130.80000000002156, 479.19999999998043]
# KEY: RIGHT
# True 1 [300, 580] [130.60000000002157, 479.3999999999804]
# KEY: DOWN
# True 1 [300, 580] [130.40000000002158, 479.5999999999804]
# KEY: LEFT
# True 1 [300, 580] [130.2000000000216, 479.7999999999804]
# KEY: RIGHT
# True 1 [300, 580] [130.0000000000216, 479.9999999999804]
# KEY: UP
# True 1 [300, 570] [129.8000000000216, 480.1999999999804]
# KEY: LEFT
# True 1 [300, 570] [129.60000000002162, 480.39999999998037]
# KEY: DOWN
# True 1 [300, 580] [129.40000000002163, 480.59999999998035]
# KEY: DOWN
# True 1 [300, 580] [129.20000000002165, 480.79999999998034]
# KEY: UP
# True 1 [300, 570] [129.00000000002166, 480.99999999998033]
# KEY: LEFT
# True 1 [300, 570] [128.80000000002167, 481.1999999999803]
# KEY: DOWN
# True 1 [300, 580] [128.60000000002168, 481.3999999999803]
# KEY: DOWN
# True 1 [300, 580] [128.4000000000217, 481.5999999999803]
# KEY: LEFT
# True 1 [300, 580] [128.2000000000217, 481.7999999999803]
# KEY: DOWN
# True 1 [300, 580] [128.0000000000217, 481.9999999999803]
# KEY: UP
# True 1 [300, 570] [127.80000000002171, 482.19999999998026]
# KEY: LEFT
# True 1 [300, 570] [127.60000000002171, 482.39999999998025]
# KEY: DOWN
# True 1 [300, 580] [127.4000000000217, 482.59999999998024]
# KEY: LEFT
# True 1 [300, 580] [127.2000000000217, 482.79999999998023]
# KEY: UP
# True 1 [300, 570] [127.0000000000217, 482.9999999999802]
# KEY: RIGHT
# True 1 [300, 570] [126.8000000000217, 483.1999999999802]
# KEY: DOWN
# True 1 [300, 580] [126.6000000000217, 483.3999999999802]
# KEY: UP
# True 1 [300, 570] [126.40000000002169, 483.5999999999802]
# KEY: RIGHT
# True 1 [300, 570] [126.20000000002169, 483.7999999999802]
# KEY: UP
# True 1 [300, 560] [126.00000000002169, 483.99999999998016]
# KEY: LEFT
# True 1 [300, 560] [125.80000000002168, 484.19999999998015]
# KEY: LEFT
# True 1 [300, 560] [125.60000000002168, 484.39999999998014]
# KEY: UP
# True 1 [300, 550] [125.40000000002168, 484.5999999999801]
# KEY: RIGHT
# True 1 [300, 550] [125.20000000002167, 484.7999999999801]
# KEY: LEFT
# True 1 [300, 550] [125.00000000002167, 484.9999999999801]
# KEY: LEFT
# True 1 [300, 550] [124.80000000002167, 485.1999999999801]
# KEY: RIGHT
# True 1 [300, 550] [124.60000000002167, 485.3999999999801]
# KEY: UP
# True 1 [300, 540] [124.40000000002166, 485.59999999998007]
# KEY: DOWN
# True 1 [300, 560] [124.20000000002166, 485.79999999998006]
# KEY: LEFT
# True 1 [300, 560] [124.00000000002166, 485.99999999998005]
# KEY: RIGHT
# True 1 [300, 560] [123.80000000002165, 486.19999999998004]
# KEY: RIGHT
# True 1 [300, 560] [123.60000000002165, 486.39999999998]
# KEY: LEFT
# True 1 [300, 560] [123.40000000002165, 486.59999999998]
# KEY: UP
# True 1 [300, 550] [123.20000000002165, 486.79999999998]
# KEY: DOWN
# True 1 [300, 570] [123.00000000002164, 486.99999999998]
# KEY: UP
# True 1 [300, 560] [122.80000000002164, 487.19999999998]
# KEY: LEFT
# True 1 [300, 560] [122.60000000002164, 487.39999999997997]
# KEY: RIGHT
# True 1 [300, 560] [122.40000000002163, 487.59999999997996]
# KEY: UP
# True 1 [300, 550] [122.20000000002163, 487.79999999997995]
# KEY: RIGHT
# True 1 [300, 550] [122.00000000002163, 487.99999999997993]
# KEY: DOWN
# True 1 [300, 570] [121.80000000002163, 488.1999999999799]
# KEY: RIGHT
# True 1 [300, 570] [121.60000000002162, 488.3999999999799]
# KEY: UP
# True 1 [300, 560] [121.40000000002162, 488.5999999999799]
# KEY: LEFT
# True 1 [300, 560] [121.20000000002162, 488.7999999999799]
# KEY: RIGHT
# True 1 [300, 560] [121.00000000002161, 488.9999999999799]
# KEY: DOWN
# True 1 [300, 580] [120.80000000002161, 489.19999999997987]
# KEY: LEFT
# True 1 [300, 580] [120.60000000002161, 489.39999999997985]
# KEY: LEFT
# True 1 [300, 580] [120.4000000000216, 489.59999999997984]
# KEY: LEFT
# True 1 [300, 580] [120.2000000000216, 489.79999999997983]
# KEY: RIGHT
# True 1 [300, 580] [120.0000000000216, 489.9999999999798]
# KEY: UP
# True 1 [300, 570] [119.8000000000216, 490.1999999999798]
# KEY: DOWN
# True 1 [300, 580] [119.6000000000216, 490.3999999999798]
# KEY: LEFT
# True 1 [300, 580] [119.40000000002159, 490.5999999999798]
# KEY: UP
# True 1 [300, 570] [119.20000000002159, 490.7999999999798]
# KEY: RIGHT
# True 1 [300, 570] [119.00000000002159, 490.99999999997976]
# KEY: DOWN
# True 1 [300, 580] [118.80000000002158, 491.19999999997975]
# KEY: DOWN
# True 1 [300, 580] [118.60000000002158, 491.39999999997974]
# KEY: UP
# True 1 [300, 570] [118.40000000002158, 491.59999999997973]
# KEY: DOWN
# True 1 [300, 580] [118.20000000002157, 491.7999999999797]
# KEY: RIGHT
# True 1 [300, 580] [118.00000000002157, 491.9999999999797]
# KEY: UP
# True 1 [300, 570] [117.80000000002157, 492.1999999999797]
# KEY: UP
# True 1 [300, 560] [117.60000000002157, 492.3999999999797]
# KEY: DOWN
# True 1 [300, 580] [117.40000000002156, 492.5999999999797]
# KEY: LEFT
# True 1 [300, 580] [117.20000000002156, 492.79999999997966]
# KEY: LEFT
# True 1 [300, 580] [117.00000000002156, 492.99999999997965]
# KEY: RIGHT
# True 1 [300, 580] [116.80000000002156, 493.19999999997964]
# KEY: UP
# True 1 [300, 570] [116.60000000002155, 493.3999999999796]
# KEY: UP
# True 1 [300, 560] [116.40000000002155, 493.5999999999796]
# KEY: DOWN
# True 1 [300, 580] [116.20000000002155, 493.7999999999796]
# KEY: RIGHT
# True 1 [300, 580] [116.00000000002154, 493.9999999999796]
# KEY: LEFT
# True 1 [300, 580] [115.80000000002154, 494.1999999999796]
# KEY: UP
# True 1 [300, 570] [115.60000000002154, 494.39999999997957]
# KEY: DOWN
# True 1 [300, 580] [115.40000000002154, 494.59999999997956]
# KEY: UP
# True 1 [300, 570] [115.20000000002153, 494.79999999997955]
# KEY: DOWN
# True 1 [300, 580] [115.00000000002153, 494.99999999997954]
# KEY: UP
# True 1 [300, 570] [114.80000000002153, 495.1999999999795]
# KEY: UP
# True 1 [300, 560] [114.60000000002152, 495.3999999999795]
# KEY: UP
# True 1 [300, 550] [114.40000000002152, 495.5999999999795]
# KEY: LEFT
# True 1 [300, 550] [114.20000000002152, 495.7999999999795]
# KEY: LEFT
# True 1 [300, 550] [114.00000000002152, 495.9999999999795]
# KEY: UP
# True 1 [300, 540] [113.80000000002151, 496.19999999997947]
# KEY: RIGHT
# True 1 [300, 540] [113.60000000002151, 496.39999999997946]
# KEY: LEFT
# True 1 [300, 540] [113.4000000000215, 496.59999999997945]
# KEY: LEFT
# True 1 [300, 540] [113.2000000000215, 496.79999999997943]
# KEY: LEFT
# True 1 [300, 540] [113.0000000000215, 496.9999999999794]
# KEY: UP
# True 1 [300, 530] [112.8000000000215, 497.1999999999794]
# KEY: RIGHT
# True 1 [300, 530] [112.6000000000215, 497.3999999999794]
# KEY: UP
# True 1 [300, 520] [112.40000000002149, 497.5999999999794]
# KEY: DOWN
# True 1 [300, 540] [112.20000000002149, 497.7999999999794]
# KEY: LEFT
# True 1 [300, 540] [112.00000000002149, 497.99999999997937]
# KEY: DOWN
# True 1 [300, 560] [111.80000000002148, 498.19999999997935]
# KEY: UP
# True 1 [300, 550] [111.60000000002148, 498.39999999997934]
# KEY: LEFT
# True 1 [300, 550] [111.40000000002148, 498.59999999997933]
# KEY: RIGHT
# True 1 [300, 550] [111.20000000002148, 498.7999999999793]
# KEY: RIGHT
# True 1 [300, 550] [111.00000000002147, 498.9999999999793]
# KEY: UP
# True 1 [300, 540] [110.80000000002147, 499.1999999999793]
# KEY: RIGHT
# True 1 [300, 540] [110.60000000002147, 499.3999999999793]
# KEY: RIGHT
# True 1 [300, 540] [110.40000000002146, 499.5999999999793]
# KEY: UP
# True 1 [300, 530] [110.20000000002146, 499.79999999997926]
# KEY: UP
# True 1 [300, 520] [110.00000000002146, 499.99999999997925]
# KEY: UP
# False 1 [300, 510] [109.80000000002146, 500.19999999997924]
